# %%
import pandas as pd
import numpy as np
from nltk.corpus import stopwords
import re
from nltk.tokenize import  word_tokenize
import json
import ast

# %%
model_name = 'ner_crf_trial3.model'
positive = True
if positive:
    train_len = 14000
    raw_data = pd.read_csv('/home/pratik/NER/data/large_positive.csv')
else:
    train_len = 25000
    raw_data = pd.read_csv('/home/pratik/NER/data/large_all.csv')

# %%
raw_data.drop_duplicates(subset=['body'], inplace=True)
len(raw_data)
# Out:
# 16623

# %%
def convert_to_list(original_text_list):
    l = ast.literal_eval(original_text_list)
    l = [i.strip() for i in l]
    return l
raw_data['original_text'] = raw_data['original_text'].apply(lambda x: convert_to_list(x))

# %%
raw_data['original_text']
# Out:
# 0                [swimming pools]
# 1                   [sports club]
# 2                 [medical store]
# 3                          [food]
# 5                           [atm]
# 6                   [petrol pump]
# 7            [kvbank deposit atm]
# 8          [kvb bank deposit atm]
# 9                [online booking]
# 10             [paytm debit card]
# 11                    [something]
# 12                  [paytm debit]
# 13                     [obc bank]
# 14                   [Night Club]
# 15          [registration center]
# 16                    [locations]
# 17                     [madikere]
# 18                  [picnic spot]
# 19                [bhaddd me jau]
# 20                    [wesa kuvh]
# 21              [cabinet painter]
# 22                    [axis bank]
# 23               [tourist places]
# 24                     [jabalpur]
# 25              [barbeque nation]
# 26                      [batches]
# 27                       [sendwa]
# 28                  [croma store]
# 29                      [anymore]
# 30                [hdfc bank atm]
#                    ...
# 21287    [heena corporation chas]
# 21288              [vashno dhaba]
# 21289                     [hotel]
# 21290                      [Koya]
# 21291                   [parlour]
# 21292                       [bar]
# 21293                   [bustand]
# 21294              [ent hospital]
# 21295                [icici bank]
# 21296                   [Fitness]
# 21297     [wholesale cloth store]
# 21298        [kill all, humanity]
# 21299                [water park]
# 21301              [beauty salon]
# 21302               [food courts]
# 21304                      [weed]
# 21305               [PETROL PUMP]
# 21306    [samsung service center]
# 21307               [petrol pump]
# 21309                     [pizza]
# 21310             [mobiles shops]
# 21311                 [bear shop]
# 21312    [india insurance office]
# 21313                     [hotel]
# 21316               [post office]
# 21318                 [axis bank]
# 21319              [Cinema House]
# 21320               [restaurants]
# 21321                     [salon]
# 21322                       [koi]
# Name: original_text, Length: 16623, dtype: object

# %%
def pre_process_text(body, original_text_list):
    try:
        processed_data = []
        tokenized_body = word_tokenize(str(body))
        processed_original_text = []
        for  original_text in original_text_list:
            processed_original_text = processed_original_text + word_tokenize(original_text.lower())
        for token in tokenized_body:
            if token.lower() in processed_original_text:
                processed_data.append((token, 'N'))
            else:
                processed_data.append((token, 'I'))
    except:
        print(body, original_text_list)
    return processed_data

# %%
processed_list = []
for body, original_text in zip(raw_data['body'], raw_data['original_text']):
    processed_list.append(pre_process_text(body, original_text))

# %%
raw_data['processed'] = list(processed_list)

# %%
docs = list(raw_data['processed'])
docs
# Out:
# [[('Swimming', 'N'), ('pools', 'N'), ('near', 'I'), ('me', 'I')],
#  [('Sports', 'N'), ('club', 'N')],
#  [('Hey', 'I'),
#   (',', 'I'),
#   ('can', 'I'),
#   ('you', 'I'),
#   ('find', 'I'),
#   ('me', 'I'),
#   ('the', 'I'),
#   ('nearest', 'I'),
#   ('medical', 'N'),
#   ('store', 'N'),
#   ('?', 'I')],
#  [('More', 'I'), ('Nearby', 'I'), (':', 'I'), ('food', 'N')],
#  [('Hey', 'I'),
#   (',', 'I'),
#   ('can', 'I'),
#   ('you', 'I'),
#   ('find', 'I'),
#   ('me', 'I'),
#   ('the', 'I'),
#   ('nearest', 'I'),
#   ('ATM', 'N'),
#   ('?', 'I')],
#  [('Hey', 'I'),
#   (',', 'I'),
#   ('can', 'I'),
#   ('you', 'I'),
#   ('find', 'I'),
#   ('me', 'I'),
#   ('the', 'I'),
#   ('nearest', 'I'),
#   ('petrol', 'N'),
#   ('pump', 'N'),
#   ('?', 'I')],
#  [('Kvbank', 'N'), ('deposit', 'N'), ('atm', 'N')],
#  [('KVB', 'N'), ('bank', 'N'), ('deposit', 'N'), ('atm', 'N')],
#  [('Online', 'N'), ('booking', 'N')],
#  [('Hey', 'I'),
#   ('I', 'I'),
#   ('want', 'I'),
#   ('Paytm', 'N'),
#   ('debit', 'N'),
#   ('card', 'N'),
#   ('queries', 'I'),
#   ('number', 'I')],
#  [('Look', 'I'), ('for', 'I'), ('something', 'N'), ('else', 'I')],
#  [('No', 'I'),
#   ('I', 'I'),
#   ('ask', 'I'),
#   ('Paytm', 'N'),
#   ('debit', 'N'),
#   ('card', 'I'),
#   ('queries', 'I')],
#  [('Obc', 'N'), ('bank', 'N'), ('in', 'I'), ('mathura', 'I'), ('up', 'I')],
#  [('More', 'I'), ('Nearby', 'I'), (':', 'I'), ('Night', 'N'), ('Club', 'N')],
#  [('Aadhar', 'I'), ('no', 'I'), ('registration', 'N'), ('center', 'N')],
#  [('Not', 'I'), ('locations', 'N')],
#  [('In', 'I'), ('Madikere', 'N')],
#  [('Picnic', 'N'), ('spot', 'N')],
#  [('Bhaddd', 'N'), ('me', 'N'), ('jau', 'N')],
#  [('To', 'I'), ('wesa', 'N'), ('kuvh', 'N')],
#  [('Cabinet', 'N'), ('painter', 'N')],
#  [('Axis', 'N'), ('bank', 'N')],
#  [('Tourist', 'N'), ('places', 'N')],
#  [('I', 'I'), ('want', 'I'), ('to', 'I'), ('go', 'I'), ('jabalpur', 'N')],
#  [('Barbeque', 'N'), ('nation', 'N'), ('near', 'I'), ('yehalanka', 'I')],
#  [('i', 'I'),
#   ('m', 'I'),
#   ('looking', 'I'),
#   ('for', 'I'),
#   ('morning', 'I'),
#   ('batches', 'N')],
#  [('Sendwa', 'N')],
#  [('Croma', 'N'),
#   ('store', 'N'),
#   ('near', 'I'),
#   ('me', 'I'),
#   ('.', 'I'),
#   ('Need', 'I'),
#   ('contact', 'I'),
#   ('number', 'I')],
#  [('Anymore', 'N'), ('?', 'I')],
#  [('HDFC', 'N'), ('Bank', 'N'), ('atm', 'N')],
#  [('Nearby', 'I'), ('services', 'N')],
#  [('Zuma', 'N'), ('classes', 'N')],
#  [('More', 'I'), ('Nearby', 'I'), (':', 'I'), ('Hotel', 'N')],
#  [('Where', 'I'), ('essar', 'N'), ('petrol', 'N'), ('filling', 'N')],
#  [('Location', 'N'), ('wrong', 'N')],
#  [('Essar', 'N'), ('petroleum', 'N'), ('filling', 'N')],
#  [('United', 'N'), ('bank', 'N'), ('of', 'N'), ('india', 'N'), ('atm', 'N')],
#  [('Amazon', 'N')],
#  [('near', 'I'), ('by', 'I'), ('spa', 'N')],
#  [('Hi', 'I'),
#   ('can', 'I'),
#   ('u', 'I'),
#   ('find', 'I'),
#   ('paramedical', 'N'),
#   ('college', 'N'),
#   ('in', 'I'),
#   ('haryana', 'I')],
#  [('Restaurant', 'N'), ('cheapest', 'I')],
#  [('Must', 'I'), ('view', 'I'), ('places', 'N')],
#  [('Near', 'N'), ('within', 'I'), ('4km', 'I')],
#  [('Sex', 'N'), ('place', 'N')],
#  [('Ya', 'N')],
#  [('Sbi', 'N')],
#  [('Hyderabad', 'N')],
#  [('We', 'I'), ('can', 'I'), ('visit', 'N')],
#  [('Can', 'I'), ('I', 'I'), ('call', 'I'), ('u', 'N')],
#  [('Why', 'I'),
#   ('u', 'I'),
#   ('sending', 'I'),
#   ('me', 'I'),
#   ('same', 'N'),
#   ('msg', 'N')],
#  [('And', 'I'),
#   ('please', 'I'),
#   ('sent', 'I'),
#   ('branch', 'I'),
#   ('address', 'I'),
#   ('not', 'I'),
#   ('ATM', 'N'),
#   ('?', 'I')],
#  [('More', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Railway', 'N'),
#   ('Station', 'N')],
#  [('KVB', 'N'), ('atm', 'N')],
#  [('Need', 'I'), ('plumber', 'N')],
#  [('More', 'I'), ('Nearby', 'I'), (':', 'I'), ('Bus', 'N'), ('Stop', 'N')],
#  [('I', 'I'),
#   ('want', 'I'),
#   ('to', 'I'),
#   ('searching', 'I'),
#   ('room', 'N'),
#   ('rents', 'N'),
#   ('in', 'I'),
#   ('Chamrajpet', 'I'),
#   ('.', 'I'),
#   ('BANGALORE', 'I')],
#  [('For', 'I'), ('ultrasound', 'N')],
#  [('Gyms', 'N'), ('nearby', 'I'), ('me', 'I')],
#  [('Near', 'I'),
#   ('by', 'I'),
#   ('travel', 'I'),
#   ('agencies', 'N'),
#   ('for', 'I'),
#   ('bus', 'N'),
#   ('booking', 'N')],
#  [('Jo', 'N'),
#   ('puch', 'N'),
#   ('rha', 'I'),
#   ('hu', 'I'),
#   ('wo', 'I'),
#   ('btu', 'I')],
#  [('Find', 'I'), ('xerox', 'N'), ('shops', 'N'), ('near', 'I'), ('me', 'I')],
#  [('Near', 'I'), ('yehalanka', 'N')],
#  [('Barbeque', 'N'), ('nation', 'N'), ('near', 'I'), ('yelanka', 'I')],
#  [('Location', 'N')],
#  [('Out', 'I'), ('of', 'I'), ('jamanagr', 'N')],
#  [('Find', 'I'), ('night', 'N'), ('club', 'N'), ('near', 'I'), ('me', 'I')],
#  [('Find', 'I'), ('hospitals', 'N'), ('near', 'I'), ('me', 'I')],
#  [('dear', 'I'),
#   ('i', 'I'),
#   ('m', 'I'),
#   ('looking', 'I'),
#   ('for', 'I'),
#   ('classes', 'I'),
#   ('of', 'I'),
#   ('tybcom..not.foe', 'I'),
#   ('railway', 'N'),
#   ('station', 'N')],
#  [('Railways', 'N'), ('enquiry', 'N')],
#  [('Zumba', 'N'), ('classes', 'N'), ('in', 'I'), ('sahibabad', 'I')],
#  [('United', 'N'), ('bank', 'N'), ('of', 'N'), ('india', 'N')],
#  [('Bus', 'N'), ('stop', 'N')],
#  [('Csn', 'I'),
#   ('I', 'I'),
#   ('have', 'I'),
#   ('Amazon', 'I'),
#   ('India', 'N'),
#   ('customer', 'N'),
#   ('care', 'N'),
#   ('number', 'I')],
#  [('More', 'I'), ('Nearby', 'I'), (':', 'I'), ('gym', 'N'), ('center', 'N')],
#  [('Hariyana', 'N'), ('bhiwani', 'N')],
#  [('nic', 'N')],
#  [('Airtel', 'N'), ('prepaid', 'N'), ('outlet', 'N')],
#  [('Near', 'I'), ('railway', 'N')],
#  [('buffet', 'N')],
#  [('Gps', 'N'), ('on', 'N')],
#  [('Same', 'I'), ('to', 'I'), ('u', 'N')],
#  [('Atc', 'N'), ('transport', 'N')],
#  [('Route', 'N'), ('please', 'I')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Essar', 'N')],
#  [('*More*', 'I'), ('Nearby', 'I'), (':', 'I'), ('Gym', 'N')],
#  [('I', 'I'),
#   ('want', 'I'),
#   ('to', 'I'),
#   ('buy', 'I'),
#   ('a', 'I'),
#   ('loptop', 'N')],
#  [('Kvbank', 'I'), ('amount', 'I'), ('deposit', 'N'), ('atm', 'N')],
#  [('Restaurant', 'N')],
#  [('How', 'I'),
#   ('would', 'I'),
#   ('I', 'I'),
#   ('be', 'I'),
#   ('able', 'I'),
#   ('to', 'I'),
#   ('book', 'I'),
#   ('msrtc', 'N'),
#   ('bus', 'N'),
#   ('from', 'I'),
#   ('Hinjwadi', 'I'),
#   ('to', 'I'),
#   ('nashik', 'I')],
#  [('More', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('shopping', 'N'),
#   ('mall', 'N')],
#  [('Hdfc', 'N'), ('bank', 'N'), ('atm', 'N'), ('machine', 'I')],
#  [('How', 'I'),
#   ('much', 'I'),
#   ('discount', 'N'),
#   ('they', 'I'),
#   ('offer', 'N')],
#  [('Danavgere', 'I'), ('rly', 'N'), ('station', 'N')],
#  [('Which', 'I'),
#   ('all', 'I'),
#   ('collges', 'N'),
#   ('are', 'I'),
#   ('dere', 'N'),
#   ('near', 'I'),
#   ('by', 'I'),
#   ('my', 'I'),
#   ('area', 'I')],
#  [('More', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('travel', 'N'),
#   ('agency', 'N')],
#  [('Arts', 'N'), ('n', 'N'), ('science', 'N'), ('college', 'N')],
#  [('Bank', 'N'), ('of', 'N'), ('brodra', 'N'), ('atm', 'N')],
#  [('More', 'I'), ('Nearby', 'I'), (':', 'I'), ('Bank', 'N')],
#  [('Plz', 'I'),
#   ('let', 'I'),
#   ('me', 'I'),
#   ('know', 'I'),
#   ('near', 'I'),
#   ('by', 'I'),
#   ('visiting', 'N'),
#   ('places', 'N'),
#   ('to', 'I'),
#   ('go', 'I')],
#  [('More', 'I'), ('Nearby', 'I'), (':', 'I'), ('jamnagar', 'N')],
#  [('Natural', 'I'),
#   ('icecream', 'N'),
#   ('parlour', 'N'),
#   ('in', 'I'),
#   ('sion', 'I'),
#   ('East', 'I')],
#  [('Plz', 'I'),
#   ('tell', 'I'),
#   ('me', 'I'),
#   ('about', 'I'),
#   ('best', 'I'),
#   ('ssc', 'N'),
#   ('coaching', 'N'),
#   ('in', 'I'),
#   ('new', 'I'),
#   ('delhi', 'I')],
#  [('Hey', 'I'),
#   ('can', 'I'),
#   ('you', 'I'),
#   ('tell', 'I'),
#   ('me', 'I'),
#   ('wine', 'I'),
#   ('and', 'I'),
#   ('beer', 'N'),
#   ('shop', 'N'),
#   ('where', 'I'),
#   ('I', 'I'),
#   ('can', 'I'),
#   ('find', 'I'),
#   ('good', 'I'),
#   ('quality', 'I'),
#   ('beer', 'N')],
#  [('Siv', 'N'), ('ganga', 'N'), ('transport', 'N')],
#  [('More', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Furniture', 'N'),
#   ('Painter', 'N')],
#  [('Until', 'I'),
#   ('that', 'I'),
#   ('u', 'I'),
#   ('can', 'I'),
#   ('send', 'I'),
#   ('next', 'I'),
#   ('property', 'N')],
#  [('Union', 'N'), ('Bank', 'N'), ('of', 'N'), ('India', 'N')],
#  [('HDFC', 'N')],
#  [('Train', 'N'), ('for', 'I'), ('jabalpur', 'I')],
#  [('More', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('uco', 'N'),
#   ('bank', 'N'),
#   ('near', 'N'),
#   ('by', 'N'),
#   ('me', 'N')],
#  [('Uco', 'N'), ('bank', 'N'), ('in', 'I'), ('Pune', 'I'), ('412307', 'I')],
#  [('Karate', 'N'), ('classes', 'N')],
#  [('Uco', 'N'), ('bank', 'N'), ('near', 'N'), ('by', 'I'), ('412307', 'I')],
#  [('Train', 'N')],
#  [('Zumba', 'N')],
#  [('Wine', 'N'), ('shop', 'N')],
#  [('Oh', 'N'), ('great', 'N'), ('!', 'I')],
#  [('Please', 'I'),
#   ('tell', 'I'),
#   ('me', 'I'),
#   ('hotel', 'N'),
#   ('near', 'I'),
#   ('Baruipur', 'I'),
#   ('Kolkata', 'I')],
#  [('I', 'I'), ('want', 'I'), ('learn', 'I'), ('horoscope', 'N')],
#  [('Amazon', 'I'), ('customer', 'N'), ('care', 'N')],
#  [('More', 'I'), ('Nearby', 'I'), (':', 'I'), ('restaurant', 'N')],
#  [('All', 'I'), ('atm', 'N'), ('link', 'I'), ('fel', 'I')],
#  [('*More*', 'I'), ('Nearby', 'I'), (':', 'I'), ('Garden', 'N')],
#  [('near', 'I'), ('by', 'I'), ('bear', 'N'), ('shop', 'N')],
#  [('resorted', 'N')],
#  [('Panipuri', 'N')],
#  [('All', 'I'),
#   ('the', 'I'),
#   ('shipping', 'N'),
#   ('ports', 'N'),
#   ('in', 'I'),
#   ('Canada', 'I')],
#  [('Any', 'I'), ('oyo', 'N'), ('rooms', 'N')],
#  [('Narayana', 'N'), ('school', 'N')],
#  [('More', 'I'), ('Nearby', 'I'), (':', 'I'), ('Beauty', 'N'), ('Salon', 'N')],
#  [('😋amazing', 'I')],
#  [('More', 'I'), ('Nearby', 'I'), (':', 'I'), ('Gym', 'N')],
#  [('More', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Railway', 'N'),
#   ('station', 'N')],
#  [('Swimming', 'N'),
#   ('pool', 'N'),
#   ('near', 'I'),
#   ('within', 'I'),
#   ('4km', 'I')],
#  [('More', 'I'), ('Nearby', 'I'), (':', 'I'), ('pub', 'N')],
#  [('I', 'I'),
#   ('want', 'I'),
#   ('to', 'I'),
#   ('know', 'I'),
#   ('the', 'I'),
#   ('entry', 'I'),
#   ('fees', 'I'),
#   ('of', 'I'),
#   ('the', 'I'),
#   ('pubs', 'N'),
#   ('near', 'I'),
#   ('me', 'I')],
#  [('*More*', 'I'), ('Nearby', 'I'), (':', 'I'), ('Hospital', 'N')],
#  [('SBI', 'N'), ('ATM', 'N')],
#  [('Is', 'I'), ('there', 'I'), ('Chamrajpet', 'N')],
#  [('Deccan', 'N'), ('gymkhnna', 'N')],
#  [('Nearby', 'I'), ('sbi', 'N'), ('bank', 'N'), ('please', 'I')],
#  [('Customer', 'N')],
#  [('Issue', 'N')],
#  [('Jamnagar', 'N'), ('gujrat', 'I')],
#  [('Find', 'I'), ('chemist', 'N'), ('near', 'I'), ('me', 'I')],
#  [('Icecream', 'N'), ('parlour', 'N')],
#  [('I', 'I'),
#   ('.', 'I'),
#   ('Am', 'I'),
#   ('going', 'I'),
#   ('to', 'I'),
#   ('airport', 'N')],
#  [('Can', 'I'),
#   ('u', 'I'),
#   ('help', 'I'),
#   ('with', 'I'),
#   ('some', 'I'),
#   ('online', 'N'),
#   ('medicines', 'N'),
#   ('discount', 'N'),
#   ('with', 'I'),
#   ('home', 'I'),
#   ('delivery', 'I')],
#  [('Sweet', 'N'), ('shop', 'N')],
#  [('Nearest', 'I'), ('market', 'N')],
#  [('Current', 'I'),
#   ('location', 'I'),
#   ('is', 'I'),
#   ('office', 'N'),
#   ('...', 'I')],
#  [('Gym', 'N'),
#   ('near', 'I'),
#   ('near', 'I'),
#   ('Street', 'I'),
#   ('Number', 'I'),
#   ('98', 'I'),
#   ('Action', 'I'),
#   ('Area1A', 'I'),
#   ('Newtown', 'I'),
#   (',', 'I'),
#   ('Kolkata', 'I'),
#   (',', 'I'),
#   ('West', 'I'),
#   ('Bengal', 'I')],
#  [('leave', 'N')],
#  [('Can', 'I'),
#   ('u', 'I'),
#   ('find', 'I'),
#   ('me', 'I'),
#   ('a', 'I'),
#   ('nearby', 'I'),
#   ('gym', 'N')],
#  [('Can', 'I'),
#   ('u', 'I'),
#   ('find', 'I'),
#   ('true', 'I'),
#   ('love', 'N'),
#   ('for', 'I'),
#   ('me', 'I')],
#  [('Do', 'I'), ('u', 'I'), ('go', 'I'), ('to', 'I'), ('gym', 'N')],
#  [('Gym', 'N'), ('in', 'I'), ('Newtown', 'I')],
#  [('Hi', 'I'),
#   ('can', 'I'),
#   ('u', 'I'),
#   ('find', 'I'),
#   ('paramedical', 'N'),
#   ('college', 'N'),
#   ('in', 'I'),
#   ('bhiwani', 'I'),
#   ('city', 'I'),
#   ('.', 'I'),
#   ('Or', 'I'),
#   ('near', 'I'),
#   ('by', 'I')],
#  [('Bangalore', 'I'), ('airport', 'N'), ('root', 'I')],
#  [('I', 'I'), ('want', 'I'), ('railway', 'N'), ('timetable', 'N')],
#  [('Axis', 'N'), ('Atm', 'N')],
#  [('*More*', 'I'), ('Nearby', 'I'), (':', 'I'), ('Pet', 'N'), ('shop', 'N')],
#  [('Find', 'I'), ('me', 'I'), ('a', 'I'), ('hotel', 'N')],
#  [('In', 'I'), ('madikere', 'N')],
#  [('Cs', 'N'),
#   ('foundation', 'N'),
#   ('coaching', 'N'),
#   ('near', 'I'),
#   ('me', 'I')],
#  [('Summer', 'N'), ('classes', 'N')],
#  [('Kheria', 'N'), ('Mode', 'N')],
#  [('nice', 'N')],
#  [('Natural', 'N'), ('icecream', 'N'), ('parlour', 'N')],
#  [('Restaurants', 'N'), ('under', 'I'), ('500', 'I'), ('meters', 'I')],
#  [('Like', 'I'), ('dwarica', 'N')],
#  [('Call', 'N')],
#  [('Try', 'I'), ('tin', 'N')],
#  [('More', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('cheap', 'N'),
#   ('restaurants', 'N')],
#  [('Kya', 'N'), ('bakr', 'N'), ('hai', 'N'), ('yr', 'I')],
#  [('Essensuals', 'N')],
#  [('Any', 'I'),
#   ('oraganic', 'I'),
#   ('or', 'I'),
#   ('healthy', 'N'),
#   ('food', 'N'),
#   ('store', 'N'),
#   (',', 'I'),
#   ('m', 'I')],
#  [('Government', 'N'), ('hospital', 'N')],
#  [('Any', 'I'),
#   ('united', 'N'),
#   ('bank', 'N'),
#   ('of', 'N'),
#   ('india', 'N'),
#   ('atm', 'N')],
#  [('do', 'I'),
#   ('u', 'I'),
#   ('think', 'I'),
#   ('Rumy', 'I'),
#   ("'s", 'I'),
#   ('beauty', 'N'),
#   ('clinic', 'N'),
#   ('is', 'I'),
#   ('a', 'I'),
#   ('tybocm', 'I'),
#   ('classes', 'I'),
#   ('?', 'I')],
#  [('Newtown', 'N')],
#  [('More', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('tybcom', 'N'),
#   ('classes', 'N')],
#  [('Nearest', 'I'),
#   ('hotel', 'N'),
#   ('from', 'I'),
#   ('gargi', 'I'),
#   ('College', 'I'),
#   ('Baruipur', 'I')],
#  [('look', 'I'),
#   ('within', 'I'),
#   ('thane', 'I'),
#   ('and', 'I'),
#   ('Dombivali', 'N')],
#  [('Madhapur', 'N')],
#  [('More', 'I'), ('Nearby', 'I'), (':', 'I'), ('Post', 'N'), ('Office', 'N')],
#  [('Busses', 'N'), ('to', 'I'), ('mumbai', 'I')],
#  [('Restaurants', 'N'),
#   ('near', 'I'),
#   ('E.', 'I'),
#   ('M.', 'I'),
#   ('Bypass', 'I')],
#  [('Pvr', 'N')],
#  [('near', 'I'), ('by', 'I'), ('resorted', 'N')],
#  [('But', 'I'), ('8', 'I'), ('want', 'I'), ('railway', 'N'), ('time', 'N')],
#  [('It', 'I'), ('companies', 'N')],
#  [('Icici', 'N'), ('bank', 'N'), ('nearby', 'I')],
#  [('Tnx', 'N')],
#  [('Nehru', 'N'), ('planetorium', 'N')],
#  [('I', 'I'),
#   ('am', 'I'),
#   ('unable', 'I'),
#   ('to', 'I'),
#   ('find', 'I'),
#   ('essar', 'N')],
#  [('U', 'I'),
#   ('can', 'I'),
#   ('find', 'I'),
#   ('at', 'I'),
#   ('an', 'I'),
#   ('azing', 'N'),
#   ('speed', 'N')],
#  [('Hey', 'I'),
#   (',', 'I'),
#   ('I', 'I'),
#   ("'m", 'I'),
#   ('looking', 'I'),
#   ('for', 'I'),
#   ('the', 'I'),
#   ('nearest', 'I'),
#   ('ATM', 'N'),
#   ('!', 'I')],
#  [('Hey', 'I'),
#   (',', 'I'),
#   ('can', 'I'),
#   ('you', 'I'),
#   ('find', 'I'),
#   ('me', 'I'),
#   ('the', 'I'),
#   ('nearest', 'I'),
#   ('Bus', 'N'),
#   ('Stop', 'N'),
#   ('?', 'I')],
#  [('Ya', 'N'), ('off', 'N'), ('course', 'N')],
#  [('More', 'I'), ('Nearby', 'I'), (':', 'I'), ('Hospital', 'N')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Bapugram', 'N')],
#  [('Main', 'I'), ('busstop', 'N')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Parks', 'N')],
#  [('Medicine', 'N'), ('shop', 'N')],
#  [('More', 'I'), ('Nearby', 'I'), (':', 'I'), ('Airport', 'N')],
#  [('Share', 'I'), ('the', 'N'), ('location', 'N')],
#  [('Later', 'N')],
#  [('Cng', 'N')],
#  [('Shirts', 'N'), ('shop', 'N')],
#  [('Map', 'N')],
#  [('Atm', 'N')],
#  [('Fuck', 'N')],
#  [('Nearest', 'I'), ('cafe', 'N'), ('coffee', 'N'), ('day', 'I'), ('?', 'I')],
#  [('But', 'I'), ('not', 'I'), ('amazing', 'N')],
#  [('Gas', 'N'), ('station', 'N')],
#  [('More', 'I'), ('Nearby', 'I'), (':', 'I'), ('restaurants', 'N')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Godhra', 'N')],
#  [('Show', 'I'), ('me', 'I'), ('a', 'I'), ('my', 'N'), ('location', 'N')],
#  [('More', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('eye', 'N'),
#   ('hospitals', 'N')],
#  [('More', 'I'), ('Nearby', 'I'), (':', 'I'), ('Photocopier', 'N')],
#  [('So', 'N'), ('much', 'N')],
#  [('More', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Diagnostic', 'N'),
#   ('Centre', 'N')],
#  [('Post', 'N'), ('office', 'N')],
#  [('Beauty', 'N'), ('palours', 'N')],
#  [('Shirt', 'N'), ('clothes', 'N')],
#  [('I', 'I'), ('need', 'I'), ('things', 'I'), ('on', 'N'), ('rent', 'N')],
#  [('You', 'I'), ('told', 'N'), ('me', 'N')],
#  [('U', 'I'),
#   ('are', 'I'),
#   ('good', 'I'),
#   ('at', 'I'),
#   ('searching', 'I'),
#   ('atm', 'N')],
#  [('Hey', 'I'),
#   ('tell', 'I'),
#   ('me', 'I'),
#   ('about', 'I'),
#   ('this', 'I'),
#   ('app', 'N')],
#  [('Same', 'N'), ('to', 'N'), ('you', 'N')],
#  [('Can', 'I'),
#   ('you', 'I'),
#   ('tell', 'I'),
#   ('me', 'I'),
#   ('where', 'I'),
#   ('is', 'I'),
#   ('nizam', 'N'),
#   ('colony', 'N')],
#  [('Phaphat', 'N')],
#  [('City', 'N'), ('Bank', 'N'), ('atm', 'N')],
#  [('Please', 'I'),
#   ('can', 'I'),
#   ('u', 'I'),
#   ('see', 'I'),
#   ('hotels', 'N'),
#   ('near', 'I'),
#   ('me', 'I')],
#  [('Hiii', 'N'), ('Daniel', 'N')],
#  [('That', 'I'), ("'s", 'I'), ('great', 'I'), ('shilpa', 'N')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('College', 'N')],
#  [('Helfin', 'N'), ('sangma', 'N')],
#  [('Fuck', 'N'), ('off', 'N')],
#  [('You', 'N'), ('to', 'N')],
#  [('🙏', 'I'), ('done', 'N')],
#  [('Soon', 'N')],
#  [('Nearby', 'I'), ('gym', 'N')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Phaphat', 'N')],
#  [('Can', 'I'),
#   ('u', 'I'),
#   ('see', 'I'),
#   ('cricket', 'N'),
#   ('academy', 'N'),
#   ('near', 'I'),
#   ('me', 'I')],
#  [('Whore', 'N')],
#  [('Who', 'N'), ('iz', 'N')],
#  [('Can', 'I'),
#   ('you', 'I'),
#   ('find', 'I'),
#   ('the', 'I'),
#   ('nearest', 'I'),
#   ('toilet', 'N'),
#   ('?', 'I')],
#  [('BOB', 'N'), ('bank', 'N'), ('ATM', 'N'), ('near', 'I'), ('me', 'I')],
#  [('India', 'N'), ('gate', 'N')],
#  [('Kaman', 'N')],
#  [('Thnqqq', 'N'), ('abhishek', 'N')],
#  [('Badv', 'N')],
#  [('Bank', 'N'), ('sbi', 'N')],
#  [('Sorry', 'I'),
#   ('i', 'I'),
#   ('am', 'I'),
#   ('at', 'I'),
#   ('home', 'I'),
#   (',', 'I'),
#   ('heavy', 'I'),
#   ('rain', 'N'),
#   ('out', 'I'),
#   ('side', 'I')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Shilpa', 'N')],
#  [('You', 'N'), ('too', 'N')],
#  [('Daniel', 'N')],
#  [('Hey', 'I'),
#   (',', 'I'),
#   ('can', 'I'),
#   ('you', 'I'),
#   ('find', 'I'),
#   ('me', 'I'),
#   ('the', 'I'),
#   ('nearest', 'I'),
#   ('restaurant', 'N'),
#   ('?', 'I')],
#  [('Meaning', 'I'), ('of', 'I'), ('shilpa', 'N')],
#  [('jsjdhjxpzlf', 'N')],
#  [('Near', 'N'), ('me', 'N')],
#  [('Brothel', 'N')],
#  [('Beauty', 'N'), ('parlor', 'N')],
#  [('Which', 'I'), ('is', 'I'), ('nearest', 'N')],
#  [('Coffee', 'N'), ('shop', 'N')],
#  [('More', 'I'), ('Nearby', 'I'), (':', 'I'), ('wine', 'N'), ('shop', 'N')],
#  [('Tw', 'N')],
#  [('Gn', 'N')],
#  [('Hey', 'I'),
#   (',', 'I'),
#   ('can', 'I'),
#   ('you', 'I'),
#   ('find', 'I'),
#   ('a', 'I'),
#   ('beauty', 'N'),
#   ('salon', 'N'),
#   ('near', 'I'),
#   ('me', 'I'),
#   ('?', 'I')],
#  [('Gym', 'N'), ('charges', 'I')],
#  [('Aplo', 'N')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Foods', 'N'),
#   ('shop', 'N'),
#   ('howly', 'N')],
#  [('Looking', 'I'),
#   ('for', 'I'),
#   ('indusland', 'N'),
#   ('bank', 'N'),
#   ('atm', 'N')],
#  [('I', 'I'), ('want', 'I'), ('some', 'I'), ('food', 'N')],
#  [('Right', 'N'), ('now', 'N')],
#  [('Thnku', 'N')],
#  [('Which', 'I'), ('one', 'N'), ('is', 'N'), ('open', 'N'), ('now', 'I')],
#  [('how', 'I'),
#   ('can', 'I'),
#   ('i', 'I'),
#   ('easily', 'I'),
#   ('contact', 'N'),
#   ('you', 'N')],
#  [('Any', 'I'), ('bus', 'N'), ('for', 'I'), ('alobag', 'I')],
#  [('Sure', 'N'), ('but', 'I'), ('not', 'I'), ('yet', 'N')],
#  [('Snaks', 'N')],
#  [('Good', 'I'),
#   ('night', 'I'),
#   ('sweet', 'N'),
#   ('dreams', 'I'),
#   ('bye', 'I')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Mohanbari', 'N')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Hashish', 'N')],
#  [('cinema', 'N'), ('theatre', 'N')],
#  [('Satyawada', 'N')],
#  [('Iscon', 'N'), ('platinum', 'N'), ('bopal', 'N')],
#  [('Can', 'I'),
#   ('you', 'I'),
#   ('tell', 'I'),
#   ('me', 'I'),
#   ('cookery', 'N'),
#   ('class', 'N'),
#   ('near', 'I'),
#   ('pursaiwalkam', 'I'),
#   ('?', 'I')],
#  [('I', 'I'), ('am', 'I'), ('Not', 'I'), ('my', 'N'), ('near', 'N')],
#  [('muzaffurpur', 'I'),
#   ('m', 'I'),
#   ('Lenovo', 'N'),
#   ('mobile', 'N'),
#   ('servic', 'N')],
#  [('Can', 'I'),
#   ('you', 'I'),
#   ('find', 'I'),
#   ('me', 'I'),
#   ('the', 'I'),
#   ('nearest', 'I'),
#   ('ATM', 'N')],
#  [('Hyundai', 'N'), ('car', 'N'), ('showroom', 'N')],
#  [('Hlw', 'N')],
#  [('Ye', 'N'), ('atm', 'N'), ('kha', 'N')],
#  [('Than', 'N'), ('ok', 'N')],
#  [('More', 'I'), ('Nearby', 'I'), (':', 'I'), ('cinema', 'N')],
#  [('Hiiii', 'N')],
#  [('Ntg', 'N')],
#  [('Pragya', 'N'), ('kendra', 'N')],
#  [('Where', 'I'), ('is', 'I'), ('my', 'I'), ('phone', 'N')],
#  [('Price', 'I'), ('of', 'I'), ('nutrafy', 'N'), ('gc', 'N')],
#  [('Any', 'I'), ('massage', 'N'), ('parlour', 'N')],
#  [('Hey', 'I'),
#   (',', 'I'),
#   ('can', 'I'),
#   ('you', 'I'),
#   ('fine', 'I'),
#   ('me', 'I'),
#   ('the', 'I'),
#   ('nearest', 'I'),
#   ('medical', 'N'),
#   ('store', 'N'),
#   ('?', 'I')],
#  [('Please', 'I'), ('location', 'N')],
#  [('Uppunda', 'N')],
#  [('Bank', 'N')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('CNG', 'N'),
#   ('pump', 'N'),
#   ('near', 'N'),
#   ('hatidear', 'N')],
#  [('ATM', 'N'), ('near', 'I'), ('by', 'I'), ('me', 'I')],
#  [('Indi', 'N'), ('scane', 'N')],
#  [('Aadhar', 'N'), ('centre', 'N')],
#  [('Allahabad', 'N'), ('atm', 'N')],
#  [('How', 'I'),
#   ('can', 'I'),
#   ('I', 'I'),
#   ('send', 'I'),
#   ('my', 'N'),
#   ('current', 'N'),
#   ('location', 'N')],
#  [('Hospital', 'N')],
#  [('Near', 'I'), ('by', 'I'), ('cinema', 'N'), ('theatre', 'N')],
#  [('Railway', 'N'), ('station', 'N')],
#  [('Bar', 'N')],
#  [('Bus', 'N'), ('stand', 'N')],
#  [('Restaurants', 'N')],
#  [('Can', 'I'), ('you', 'I'), ('check', 'N'), ('my', 'N'), ('result', 'N')],
#  [('Nearby', 'I'), ('cinema', 'N')],
#  [('Ora', 'N'), ('bagan', 'N')],
#  [('Beliaghata', 'N')],
#  [('Bikaner', 'N'), ('petrol', 'N'), ('pump', 'N')],
#  [('Where', 'I'), ('is', 'I'), ('sachin', 'N'), ('sharma', 'N')],
#  [('Shopping', 'N'), ('clothes', 'N')],
#  [('Eating', 'N'), ('places', 'N')],
#  [('Taxi', 'N')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Dental', 'N'),
#   ('clinic', 'N')],
#  [('Give', 'I'),
#   ('me', 'I'),
#   ('the', 'I'),
#   ('bus', 'I'),
#   ('details', 'I'),
#   ('between', 'I'),
#   ('jaipur', 'I'),
#   ('to', 'I'),
#   ('jodhpur', 'I'),
#   ('timings', 'I'),
#   ('and', 'I'),
#   ('availability', 'I'),
#   ('of', 'I'),
#   ('season', 'N'),
#   ('it', 'I')],
#  [('Pic', 'N')],
#  [('Byy', 'N')],
#  [('Which', 'I'),
#   ('is', 'I'),
#   ('the', 'N'),
#   ('place', 'N'),
#   ('where', 'I'),
#   ('i', 'I'),
#   ('am', 'I'),
#   ('leaving', 'I')],
#  [('Can', 'I'),
#   ('you', 'I'),
#   ('find', 'I'),
#   ('me', 'I'),
#   ('the', 'I'),
#   ('nearest', 'I'),
#   ('Petrol', 'N'),
#   ('pump', 'N')],
#  [('Good', 'I'), ('food', 'N')],
#  [('Car', 'N'), ('Washing', 'N'), ('centres', 'N'), ('.', 'I')],
#  [('Ayu', 'I'),
#   ('health', 'N'),
#   ('clinic', 'N'),
#   ('in', 'I'),
#   ('purani', 'I'),
#   ('tehsil', 'I')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Secunderabad', 'N')],
#  [('Cake', 'N'), ('shop', 'N')],
#  [('Tifra', 'N'), ('atm', 'N')],
#  [('Means', 'N'), ('?', 'I')],
#  [('Petrol', 'N'), ('pump', 'N')],
#  [('pump', 'N')],
#  [('pune', 'I'), ('to', 'I'), ('usmanabad', 'I'), ('buses', 'N')],
#  [('pune', 'I'),
#   ('to', 'I'),
#   ('usmanabad', 'I'),
#   ('buses', 'N'),
#   ('redbus', 'I')],
#  [('prostitutions', 'N')],
#  [('Electric', 'N'), ('shop', 'N')],
#  [('Jaan', 'N')],
#  [('Apollo', 'N'), ('pharmacy', 'N')],
#  [('Can', 'I'),
#   ('you', 'I'),
#   ('tell', 'I'),
#   ('me', 'I'),
#   ('cookery', 'N'),
#   ('class', 'N'),
#   ('?', 'I')],
#  [('They', 'I'), ('do', 'I'), ('texture', 'N'), ('paint', 'N')],
#  [('Minimum', 'I'),
#   ('price', 'I'),
#   ('for', 'I'),
#   ('texture', 'N'),
#   ('wall', 'N')],
#  [('More', 'I'), ('Nearby', 'I'), (':', 'I'), ('my', 'N'), ('address', 'N')],
#  [('Spa', 'N')],
#  [('Allahabad', 'N'), ('bank', 'N')],
#  [('Allhabad', 'N'), ('bank', 'N')],
#  [('Can', 'I'), ('you', 'I'), ('calling', 'N'), ('me', 'I'), ('.', 'I')],
#  [('Can', 'I'),
#   ('you', 'I'),
#   ('Bengali', 'N'),
#   ('meaning', 'N'),
#   ('give', 'I'),
#   ('me', 'I'),
#   ('.', 'I')],
#  [('amet', 'N')],
#  [('sex', 'N')],
#  [('Facing', 'N'), ('means', 'N')],
#  [('Sweet', 'N'), ('dream', 'N')],
#  [('Not', 'I'),
#   ('as', 'I'),
#   ('this.but', 'I'),
#   ('nearer', 'I'),
#   ('multiplex', 'N')],
#  [('Jamia', 'I'),
#   ('Nagar', 'I'),
#   ('batla', 'I'),
#   ('house', 'N'),
#   ('Okhla', 'I')],
#  [('Try', 'N'), ('it', 'N')],
#  [('All', 'I'),
#   ('these', 'I'),
#   ('bunks', 'N'),
#   ('have', 'I'),
#   ('speed', 'I'),
#   ('97', 'I'),
#   ('?', 'I')],
#  [('Sbi', 'N'), ('atm', 'N'), ('mankurd', 'I')],
#  [('More', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('telenor', 'N'),
#   ('mini', 'N'),
#   ('store', 'N')],
#  [('Vishal', 'N'), ('Mega', 'N'), ('Mart', 'N'), ('Diphu', 'I')],
#  [('Thnkew', 'N')],
#  [('Hai', 'N'), ('shilpa', 'N')],
#  [('Bidhnu', 'N'), ('thana', 'N')],
#  [('Gurdwara', 'N'), ('market', 'N')],
#  [('Mt', 'N'), ('location', 'N')],
#  [('SIB', 'N'), ('CDM', 'N')],
#  [('Idfc', 'N')],
#  [('haaaa', 'N')],
#  [('Kya', 'N')],
#  [('Majestic', 'N')],
#  [('Hey', 'I'),
#   ('can', 'I'),
#   ('you', 'I'),
#   ('find', 'I'),
#   ('me', 'I'),
#   ('the', 'I'),
#   ('nearest', 'I'),
#   ('Bus', 'N'),
#   ('Stop', 'N'),
#   ('?', 'I')],
#  [('Do', 'I'),
#   ("n't", 'I'),
#   ('worry', 'I'),
#   ('...', 'I'),
#   ('i', 'I'),
#   ('will', 'I'),
#   ('manage', 'N')],
#  [('Gud', 'N')],
#  [('Photo', 'N')],
#  [('betul', 'N'), ('bazar', 'I')],
#  [('shilpa', 'N')],
#  [('I', 'I'), ('want', 'I'), ('redlight', 'N'), ('areas', 'N')],
#  [('Bakery', 'N')],
#  [('More', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Jhunjhunu', 'N'),
#   ('hdfc', 'N'),
#   ('bank', 'N')],
#  [('Hlo', 'I'), ('app', 'I'), ('kaha', 'N'), ('se', 'N'), ('ho', 'I')],
#  [('Send', 'N'), ('yor', 'I'), ('pic', 'I'), ('me', 'I')],
#  [('Vijay', 'N'), ('selc', 'N')],
#  [('Forget', 'I'),
#   ('it', 'I'),
#   ('it', 'I'),
#   ("'s", 'I'),
#   ('not', 'I'),
#   ('your', 'I'),
#   ('business', 'N')],
#  [('Show', 'N'), ('me', 'I'), ('again', 'I')],
#  [('Whos', 'N'), ('name', 'N')],
#  [('Bulter', 'N'), ('bareilly', 'I')],
#  [('Vizag', 'N')],
#  [('Hey', 'I'),
#   ('can', 'I'),
#   ('you', 'I'),
#   ('find', 'I'),
#   ('me', 'I'),
#   ('the', 'I'),
#   ('nearest', 'I'),
#   ('petrol', 'N'),
#   ('pump', 'N'),
#   ('?', 'I')],
#  [('escorting', 'N')],
#  [('More', 'I'), ('Nearby', 'I'), (':', 'I'), ('hotels', 'N')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Ateli', 'N')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'N'),
#   ('Nearby', 'N'),
#   (':', 'I'),
#   ('Nearby', 'N'),
#   ('night', 'N'),
#   ('club', 'N')],
#  [('rupees', 'N'), ('avilevel', 'N')],
#  [('RO', 'I'), ('water', 'N'), ('purifier', 'N'), ('dealer', 'N')],
#  [('Call', 'I'), ('girls', 'N'), ('in', 'I'), ('bhimavaram', 'I')],
#  [('Petrol', 'N'), ('pampu', 'N')],
#  [('Hey', 'I'),
#   ('can', 'I'),
#   ('you', 'I'),
#   ('find', 'I'),
#   ('me', 'I'),
#   ('the', 'I'),
#   ('nearest', 'I'),
#   ('ATM', 'N'),
#   ('?', 'I')],
#  [('Hotel', 'N'), ('near', 'I'), ('me', 'I')],
#  [('Chutiya', 'N')],
#  [('Sab', 'N')],
#  [('call', 'I'), ('girls', 'N')],
#  [('Gym', 'N'), ('name', 'N')],
#  [('Unisex', 'N'), ('salon', 'N')],
#  [('Really', 'N')],
#  [('Eating', 'I'), ('lunch', 'N'), ('hotel', 'N')],
#  [('More', 'I'), ('Nearby', 'I'), (':', 'I'), ('iisc', 'N')],
#  [('I', 'I'),
#   ('want', 'I'),
#   ('a', 'I'),
#   ('hotel', 'N'),
#   ('nearest', 'I'),
#   ('to', 'I'),
#   ('Acharya', 'I'),
#   ('nagarjuna', 'I'),
#   ('university', 'I')],
#  [('More', 'I'), ('Nearby', 'I'), (':', 'I'), ('hospital', 'N')],
#  [('Chek', 'N'), ('posy', 'N')],
#  [('Optician', 'N')],
#  [('Bob', 'N')],
#  [('Rajmander', 'N')],
#  [('Bye', 'N'), ('bye', 'N')],
#  [('Porn', 'N')],
#  [('Petrolpump', 'N')],
#  [('More', 'I'), ('Nearby', 'I'), (':', 'I'), ('hotel', 'N')],
#  [('beer', 'N'), ('shop', 'N')],
#  [('Restaurent', 'N')],
#  [('Whats', 'N'), ('ur', 'N'), ('job', 'N')],
#  [('No..', 'I'), ('cetrle', 'N'), ('bank', 'N'), ('of', 'N'), ('india', 'N')],
#  [('Andhara', 'N'), ('bank', 'N')],
#  [('Restaurant', 'N'), ('near', 'I'), ('by', 'I'), ('me', 'I')],
#  [('Mobile', 'N'), ('shop', 'N')],
#  [('Cng', 'N'), ('pump', 'N')],
#  [('Shri', 'N'), ('brahmani', 'I'), ('mobile', 'I'), ('nomber', 'N')],
#  [('Salon', 'N')],
#  [('House', 'N'), ('address', 'I'), ('are', 'I'), ('worng', 'I')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Godda', 'N')],
#  [('More', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('cash', 'N'),
#   ('deposit', 'N'),
#   ('machine', 'N')],
#  [('How', 'I'),
#   ('come', 'I'),
#   ('you', 'I'),
#   ('know', 'I'),
#   ('all', 'N'),
#   ('these', 'N'),
#   ('?', 'I')],
#  [('What', 'I'), ('I', 'I'), ('did', 'I'), ("n't", 'I'), ('understand', 'N')],
#  [('Hesla', 'N')],
#  [('More', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Moter', 'N'),
#   ('training', 'N'),
#   ('school', 'N')],
#  [('Cakes', 'N')],
#  [('Vada', 'N')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('kavali', 'N')],
#  [('Penis', 'N')],
#  [('Harshad', 'N'), ('chopra', 'N')],
#  [('Restorent', 'N')],
#  [('Near', 'I'), ('Sony', 'N'), ('doctor', 'N')],
#  [('Sbi', 'N'), ('atm', 'N')],
#  [('IDBI', 'N'), ('atm', 'N'), ('nearby', 'I')],
#  [('Botad', 'I'), ('police', 'N'), ('station', 'N')],
#  [('Central', 'N'), ('bank', 'N'), ('of', 'N'), ('India', 'N')],
#  [('Thanku', 'N'), ('Sir', 'N')],
#  [('Near', 'I'), ('by', 'I'), ('swimming', 'N'), ('pool', 'N')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('train', 'N')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Resturants', 'N')],
#  [('I', 'I'),
#   ('want', 'I'),
#   ('to', 'I'),
#   ('purchase', 'I'),
#   ('a', 'I'),
#   ('scooty', 'I'),
#   ('.', 'I'),
#   ('Is', 'I'),
#   ('any', 'I'),
#   ('shop', 'N'),
#   ('nearby', 'I')],
#  [('Mansoori', 'N')],
#  [('More', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('swimming', 'N'),
#   ('pool', 'N')],
#  [('A', 'I'), ('nearby', 'I'), ('restaurant', 'N')],
#  [('More', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('generap', 'N'),
#   ('store', 'N')],
#  [('Atms', 'N')],
#  [('Swimming', 'N'), ('pools', 'N')],
#  [('Best', 'I'), ('eye', 'N'), ('doctor', 'N')],
#  [('Cloud', 'N'), ('cafe', 'N')],
#  [('Palakonda', 'N')],
#  [('I', 'I'),
#   ('want', 'I'),
#   ('samalkot', 'N'),
#   ('railway', 'N'),
#   ('station', 'N'),
#   ('num', 'I')],
#  [('Actually', 'I'),
#   ('looking', 'I'),
#   ('for', 'I'),
#   ('some', 'I'),
#   ('spa', 'N')],
#  [('Dominor', 'N')],
#  [('Girls', 'N')],
#  [('Kkk', 'I'),
#   ('best', 'I'),
#   ('hair', 'N'),
#   ('hosp', 'N'),
#   ('in', 'I'),
#   ('kadapa', 'I'),
#   ('city', 'I')],
#  [('Bus', 'N')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Mobile', 'N')],
#  [('Banks', 'N')],
#  [('My', 'I'),
#   ('girlfriend', 'N'),
#   ('is', 'I'),
#   ('cheating', 'I'),
#   ('on', 'I'),
#   ('me', 'I')],
#  [('super', 'N'), ('market', 'N')],
#  [('Shope', 'N')],
#  [('For', 'I'), ('body', 'N'), ('massage', 'N')],
#  [('Kkkkk', 'I'),
#   ('best', 'I'),
#   ('and', 'I'),
#   ('famous', 'I'),
#   ('hair', 'N'),
#   ('hospital', 'N'),
#   ('for', 'I'),
#   ('hair', 'N'),
#   ('growth', 'I')],
#  [('The', 'I'),
#   ('best', 'I'),
#   ('phone', 'N'),
#   ('in', 'I'),
#   ('samsung', 'I'),
#   ('I', 'I'),
#   ('love', 'I')],
#  [('Sovabazar', 'N')],
#  [('Optical', 'N')],
#  [('I', 'I'),
#   ('do', 'I'),
#   ('not', 'I'),
#   ('understand', 'N'),
#   ('what', 'I'),
#   ('you', 'N'),
#   ('mean', 'N')],
#  [('Any', 'I'),
#   ('new', 'I'),
#   ('rauf', 'N'),
#   ('and', 'I'),
#   ('sons', 'I'),
#   ('optical', 'N'),
#   ('where', 'I'),
#   ('you', 'I'),
#   ('tell', 'I'),
#   ('me', 'I')],
#  [('Hey', 'N'), ('abhishek', 'N')],
#  [('Bhurji', 'N'), ('pav', 'N')],
#  [('Charges', 'N')],
#  [('Tim', 'I'), ('Hortons', 'N')],
#  [('Where', 'I'), ('i', 'I'), ('can', 'I'), ('find', 'I'), ('weed', 'N')],
#  [('service', 'N'), ('centre', 'N'), ('kitne', 'I'), ('h', 'I')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Any', 'N'),
#   ('kind', 'N'),
#   ('of', 'N'),
#   ('offers', 'N')],
#  [('Atm', 'N'), ('of', 'I'), ('sbi', 'N')],
#  [('Jharsuguda', 'N')],
#  [('Please', 'I'),
#   ('tell', 'I'),
#   ('me', 'I'),
#   ('nearest', 'I'),
#   ('mosque', 'N')],
#  [('Where', 'I'), ('is', 'I'), ('your', 'I'), ('home', 'N')],
#  [('Rajan', 'N')],
#  [('Mahra', 'N')],
#  [('my', 'I'), ('location', 'I'), ('is', 'I'), ('Navalur', 'N')],
#  [('Airport', 'N')],
#  [('CDM', 'N')],
#  [('Reasi', 'I'), ('atm', 'N'), ('sbi', 'N')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Pytm', 'N'),
#   ('kyc', 'N')],
#  [('Actually', 'I'), ('I', 'I'), ('need', 'I'), ('a', 'I'), ('job', 'N')],
#  [('hotels', 'N'), ('at', 'I'), ('guntur', 'I')],
#  [('Police', 'N'), ('station', 'N')],
#  [('Not', 'I'),
#   ('petrol', 'N'),
#   ('pump', 'I'),
#   ('only', 'I'),
#   ('CNG', 'N'),
#   ('pump', 'I')],
#  [('Metro', 'N'), ('station', 'N')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('CNG', 'N'),
#   ('pump', 'N'),
#   ('near', 'N'),
#   ('haridwar', 'N')],
#  [('Job', 'N')],
#  [('Sony', 'N'), ('service', 'N'), ('center', 'N')],
#  [('Sex', 'N'), ('girls', 'N')],
#  [('kisd', 'N'), ('school', 'N'), ('raipur', 'I'), ('nearby', 'I')],
#  [('Bhabhua', 'N'), ('rout', 'N')],
#  [('Airtel', 'N'), ('store', 'N')],
#  [('Ice', 'N'), ('cream', 'N'), ('store', 'N')],
#  [('ATM', 'N')],
#  [('It', 'I'), ("'s", 'I'), ('ok', 'N'), ('fine', 'N')],
#  [('Home', 'N'),
#   ('delivery', 'N'),
#   ('veg', 'N'),
#   ('food', 'N'),
#   ('near', 'I'),
#   ('me', 'I')],
#  [('Can', 'I'),
#   ('you', 'I'),
#   ('find', 'I'),
#   ('me', 'I'),
#   ('the', 'I'),
#   ('nearest', 'I'),
#   ('medical', 'N'),
#   ('store', 'N')],
#  [('Hw', 'I'),
#   ('to', 'I'),
#   ('go', 'I'),
#   ('delhi', 'I'),
#   ('easy', 'I'),
#   ('way', 'N')],
#  [('Hotels', 'N')],
#  [('Modern', 'N'), ('eye', 'N')],
#  [('Oria', 'N'), ('bagan', 'I')],
#  [('Condom', 'N'), ('use', 'I')],
#  [('Book', 'N'), ('shops', 'N')],
#  [('Nonveg', 'N'), ('hotel', 'N')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Pizza', 'N'),
#   ('hut', 'N')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Hotel', 'N')],
#  [('sory', 'N')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Prostitute', 'N')],
#  [('Calling', 'N'), ('girls', 'N'), ('nearby', 'I')],
#  [('Janta', 'N'), ('explanation', 'I')],
#  [('Dariba', 'N')],
#  [('what', 'I'), ('about', 'I'), ('uu', 'N')],
#  [('Jhunjhunu', 'I'),
#   ('hdfc', 'N'),
#   ('bank', 'N'),
#   ('call', 'N'),
#   ('no', 'I'),
#   ('.', 'I'),
#   ('find', 'I')],
#  [('47', 'I'),
#   (';', 'I'),
#   ('ambika', 'N'),
#   ('soctiy', 'N'),
#   (';', 'I'),
#   ('vijapur', 'N')],
#  [('any', 'I'), ('dentist', 'N'), ('near', 'I'), ('by', 'I')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Night', 'N'),
#   ('resort', 'N'),
#   ('stay', 'N')],
#  [('Adharcard', 'N'), ('center', 'N')],
#  [('How', 'I'),
#   ('can', 'I'),
#   ('i', 'I'),
#   ('go', 'N'),
#   ('there', 'N'),
#   ('?', 'I')],
#  [('Vanarpetai', 'N'), ('in', 'I'), ('trinelveli', 'I')],
#  [('Where', 'I'), ('is', 'I'), ('ciber', 'N'), ('caffe', 'N'), ('?', 'I')],
#  [('I', 'I'), ('m', 'I'), ('sad', 'N')],
#  [('Kotak', 'N'), ('Mahindra', 'N'), ('bank', 'N')],
#  [('Gangapur', 'N')],
#  [('Independent', 'I'), ('sex', 'N'), ('workers', 'N')],
#  [('Google', 'I'), ('is', 'I'), ('better', 'N')],
#  [('Near', 'I'), ('hesserghata', 'N')],
#  [('food', 'N')],
#  [('sex', 'N'), ('around', 'I')],
#  [('resort', 'N'), ('nearby', 'I')],
#  [('massage', 'N'), ('center', 'N')],
#  [('I', 'I'),
#   ('have', 'I'),
#   ('already', 'I'),
#   ('share', 'N'),
#   ('my', 'N'),
#   ('location', 'N')],
#  [('Sbi', 'N'), ('in', 'I'), ('durga', 'I'), ('puri', 'I')],
#  [('Dena', 'N'), ('bank', 'N')],
#  [('I', 'I'), ('want', 'I'), ('buity', 'N'), ('parlour', 'N'), ('.', 'I')],
#  [('send', 'N'), ('your', 'I'), ('pic', 'N')],
#  [('Nearby', 'I'),
#   (':', 'I'),
#   ('Jhunjhunu', 'I'),
#   ('(', 'I'),
#   ('Rajasthan', 'I'),
#   (')', 'I'),
#   ('hdfc', 'N'),
#   ('bank', 'N')],
#  [('Fooding', 'N'), ('hotel', 'N')],
#  [('sex', 'N'), ('workers', 'N')],
#  [('Bitches', 'N'), ('in', 'I'), ('bhimavaram', 'I')],
#  [('Nearby', 'I'), ('diagnostics', 'N')],
#  [('Tum', 'N'), ('kha', 'N'), ('se', 'N')],
#  [('Dana', 'N'), ('bank', 'N'), ('silvassa', 'N')],
#  [('Jhansi', 'N'), ('railway', 'N'), ('station', 'N'), ('distance', 'I')],
#  [('Samsung', 'N'), ('store', 'N')],
#  [('Its', 'I'), ('mayank', 'N'), ('from', 'I'), ('mumbai', 'I')],
#  [('Restaurant', 'N'), ('near', 'I'), ('me', 'I')],
#  [('Male', 'N'), ('escourt', 'N')],
#  [('Kids', 'N'), ('school', 'N')],
#  [('St', 'N'), ('depot', 'N'), ('near', 'I'), ('shahapur', 'I')],
#  [('No', 'I'), ('bus', 'N'), ('depot', 'N')],
#  [('Loction', 'N'), ('is', 'I'), ('on', 'I')],
#  [('Hahaha', 'N')],
#  [('Spare', 'N'), ('parts', 'N')],
#  [('Mouhiddinpur', 'N')],
#  [('kaise', 'N'), ('ho', 'N')],
#  [('I', 'I'),
#   ("'m", 'I'),
#   ('joy', 'I'),
#   ('goswami', 'I'),
#   ('..', 'I'),
#   ('from', 'I'),
#   ('mundra', 'N'),
#   ('kutchh', 'N'),
#   ('.gujarat', 'I')],
#  [('Rajkot', 'N')],
#  [('Can', 'I'), ('talk', 'I'), ('wid', 'N'), ('u', 'N')],
#  [('Jio', 'N'), ('tower', 'N')],
#  [('Bank', 'N'),
#   ('of', 'N'),
#   ('baroda', 'N'),
#   ('branch', 'I'),
#   ('in', 'I'),
#   ('bhilwara', 'I')],
#  [('Manglore', 'N'), ('stores', 'N')],
#  [('How', 'I'),
#   ('much', 'I'),
#   ('of', 'I'),
#   ('stars', 'N'),
#   ('it', 'I'),
#   ('was', 'I'),
#   ('?', 'I')],
#  [('Body', 'I'), ('massage', 'N')],
#  [('near', 'N'), ('me', 'N')],
#  [('Can', 'I'),
#   ('you', 'I'),
#   ('find', 'I'),
#   ('me', 'I'),
#   ('a', 'I'),
#   ('petrol', 'N'),
#   ('bunk', 'I'),
#   ('with', 'I'),
#   ('speed', 'I'),
#   ('97', 'I'),
#   ('?', 'I')],
#  [('Palghar', 'N')],
#  [('Beliaghata', 'N'), ('oria', 'N'), ('bagan', 'I')],
#  [('Another', 'N')],
#  [('Movie', 'N')],
#  [('Dance', 'N'), ('club', 'N')],
#  [('vh', 'N')],
#  [('Near', 'I'), ('Restorent', 'N')],
#  [('A', 'N'), ('T', 'N'), ('M', 'N')],
#  [('Nearby', 'I'), ('Hdfc', 'N'), ('bank', 'N'), ('atm', 'N')],
#  [('Adhar', 'N'), ('card', 'N'), ('center', 'N')],
#  [('Machinery', 'N'), ('shop', 'N')],
#  [('More', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('educational', 'N'),
#   ('tips', 'N')],
#  [('Ladies', 'N')],
#  [('My', 'I'),
#   ('location', 'I'),
#   ('is', 'I'),
#   ('jaipur', 'N'),
#   ('junction', 'N')],
#  [('I', 'I'), ('need', 'I'), ('girl', 'N'), ('friend', 'N')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Any', 'N'),
#   ('hangout', 'N'),
#   ('place', 'N'),
#   ('bar', 'N'),
#   ('etc', 'N')],
#  [('By', 'I'),
#   ('d', 'I'),
#   ('wy', 'I'),
#   ('.', 'I'),
#   ('Joy', 'I'),
#   ('goswami..', 'I'),
#   ('invastigation', 'I'),
#   ('oficer', 'I'),
#   ('in', 'I'),
#   ('gujarat', 'I'),
#   ('police', 'N'),
#   ('...', 'I')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Chhoch', 'N')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Gundala', 'N')],
#  [('Tower', 'N')],
#  [('Wtf', 'N')],
#  [('Snack', 'N'), ('parlour', 'N')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('So', 'N'),
#   ('nagar', 'N')],
#  [('Bol', 'N')],
#  [('Aligarh', 'N')],
#  [('Jumba', 'N'), ('in', 'I'), ('pd', 'I'), ('vihar', 'I')],
#  [('Cinemas', 'N')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('yes', 'N')],
#  [('Nearby', 'I'), ('films', 'N')],
#  [('Is', 'I'), ('there', 'I'), ('any', 'I'), ('nearby', 'I'), ('atm', 'N')],
#  [('Abe', 'I'), ('Esme', 'I'), ('kya', 'I'), ('fine', 'N'), ('kerna', 'N')],
#  [('For', 'I'), ('ladies', 'N')],
#  [('Price', 'N'), ('please', 'I')],
#  [('Goodbye', 'N')],
#  [('Sex', 'N'), ('videos', 'I')],
#  [('What', 'I'), ('about', 'I'), ('cse', 'N')],
#  [('Lakkidikapool', 'N')],
#  [('Thetre', 'N'), ('near', 'I'), ('me', 'I')],
#  [('Gym', 'N')],
#  [('Tell', 'I'),
#   ('me', 'I'),
#   ('something', 'N'),
#   ('about', 'I'),
#   ('you', 'I')],
#  [('Bu', 'N'), ('jhansi', 'N')],
#  [('Iddgah', 'N'), ('park', 'N')],
#  [('Jumba', 'N'), ('class', 'N')],
#  [('Near', 'N'), ('friends', 'N')],
#  [('Hookha', 'N'), ('bar', 'N')],
#  [('I', 'I'), ('m', 'I'), ('glad', 'N')],
#  [('Hotels', 'N'), ('?', 'I'), ('?', 'I')],
#  [('Charan', 'N'), ('singh', 'N'), ('college', 'N'), ('chirgao', 'I')],
#  [('Find', 'I'),
#   ('my', 'I'),
#   ('friends', 'N'),
#   ('near', 'I'),
#   ('to', 'I'),
#   ('me', 'I')],
#  [('Mobile', 'N')],
#  [('U', 'I'),
#   ('are', 'I'),
#   ('h', 'N'),
#   ('good', 'I'),
#   ('service', 'N'),
#   ('man', 'N')],
#  [('Chirgao', 'N')],
#  [('More', 'I'), ('Nearby', 'I'), (':', 'I'), ('dominos', 'N')],
#  [('U', 'I'),
#   ('did', 'I'),
#   ("n't", 'I'),
#   ('get', 'I'),
#   ('what', 'I'),
#   ('I', 'I'),
#   ('mean', 'I'),
#   ('.', 'I'),
#   ('I', 'I'),
#   ('want', 'I'),
#   ('to', 'I'),
#   ('buy', 'I'),
#   ('a', 'I'),
#   ('ladies', 'N'),
#   ('scooty', 'N'),
#   ('...', 'I'),
#   ('bike', 'I'),
#   ('type', 'I')],
#  [('More', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('dominose', 'N'),
#   ('pizza', 'N')],
#  [('SBI', 'N')],
#  [('Dtdc', 'N')],
#  [('Ohk', 'N')],
#  [('Any', 'I'), ('amby', 'N'), ('mata', 'N'), ('temple', 'N')],
#  [('Nothing', 'N'), ('leave', 'N')],
#  [('I', 'I'),
#   ('do', 'I'),
#   ("n't", 'I'),
#   ('hav', 'I'),
#   ('any', 'I'),
#   ('issue', 'N')],
#  [('Rajpurroad', 'N'), ('b', 'N'), ('bun', 'N')],
#  [('More', 'N'), ('options', 'N')],
#  [('eye', 'N'), ('hospital', 'N')],
#  [('Hdfc', 'N')],
#  [('Homeopathy', 'N'), ('medical', 'N')],
#  [('Hi', 'I'),
#   ('i', 'I'),
#   ('want', 'I'),
#   ('to', 'I'),
#   ('know', 'I'),
#   ('about', 'I'),
#   ('any', 'I'),
#   ('indian', 'N'),
#   ('restaurant', 'N'),
#   ('nearby', 'I'),
#   ('to', 'I'),
#   ('my', 'I'),
#   ('location', 'I')],
#  [('Bro', 'N')],
#  [('Can', 'I'),
#   ('you', 'I'),
#   ('show', 'I'),
#   ('me', 'I'),
#   ('a', 'I'),
#   ('women', 'N'),
#   ('beauty', 'N'),
#   ('salon', 'N'),
#   ('near', 'I'),
#   ('me', 'I')],
#  [('thnks', 'N'), ('bro', 'N')],
#  [('Tiffin', 'N'), ('centers', 'N')],
#  [('Varanasi', 'N')],
#  [('Pharmacy', 'N'), ('near', 'I'), ('me', 'I')],
#  [('Option', 'N')],
#  [('Please', 'I'),
#   ('fine', 'I'),
#   ('nearby', 'I'),
#   ('airtel', 'N'),
#   ('service', 'N')],
#  [('Samsung', 'N'), ('active', 'N')],
#  [('Okay', 'I'), ('baby', 'N')],
#  [('Service', 'N'), ('center', 'N'), ('of', 'I'), ('mi', 'I')],
#  [('karashn', 'N'), ('bhai', 'N')],
#  [('Shiv', 'N'), ('jewellers', 'N')],
#  [('Where', 'N'), ('it', 'N'), ('is', 'N')],
#  [('Chimest', 'N')],
#  [('Hiii', 'I'),
#   ('Can', 'I'),
#   ('I', 'I'),
#   ('get', 'I'),
#   ('information', 'I'),
#   ('about', 'I'),
#   ('nearby', 'I'),
#   ('dental', 'N'),
#   ('clinic', 'N')],
#  [('Most', 'N'), ('welcome😊', 'I')],
#  [('Badminton', 'N'), ('coach', 'N'), ('nearby', 'I')],
#  [('Where', 'N'), ('do', 'N'), ('you', 'I'), ('stay', 'N')],
#  [('I', 'I'), ('am', 'I'), ('asking', 'N'), ('you', 'N'), ('something', 'N')],
#  [('Isckon', 'N'), ('road', 'N')],
#  [('bar', 'N')],
#  [('Can', 'I'),
#   ('u', 'I'),
#   ('find', 'I'),
#   ('the', 'I'),
#   ('nearest', 'I'),
#   ('restaurant', 'N'),
#   ('near', 'I'),
#   ('me', 'I'),
#   ('?', 'I')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Panni', 'N'),
#   ('puri', 'N')],
#  [('Kadapa', 'N')],
#  [('sbi', 'N'), ('atm', 'N')],
#  [('Ys', 'N')],
#  [('Gxjgx', 'N')],
#  [('I', 'I'), ('want', 'I'), ('icici', 'N'), ('bank', 'N')],
#  [('Doctor', 'N')],
#  [('Bank', 'N'), ('of', 'N'), ('India', 'N'), ('ATM', 'N')],
#  [('Chandiput', 'N')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Wineshop', 'N')],
#  [('N', 'N'), ('wallpaper', 'N')],
#  [('Where', 'I'), ('is', 'I'), ('my', 'N'), ('girlfriend', 'N'), ('?', 'I')],
#  [('Call', 'I'), ('gairl', 'N')],
#  [('To', 'I'), ('reach', 'N'), ('kangayam', 'N'), ('?', 'I')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Cinema', 'N'),
#   ('halls', 'N')],
#  [('Big', 'N'), ('bazar', 'N')],
#  [('autogas', 'N')],
#  [('best', 'I'), ('schools', 'N'), ('in', 'I'), ('gaya', 'I')],
#  [('Nagercoli', 'N')],
#  [('Paytm', 'N'), ('shop', 'N')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Ambavde', 'N'),
#   ('phata', 'N')],
#  [('Why', 'I'),
#   ('did', 'I'),
#   ("n't", 'I'),
#   ('you', 'I'),
#   ('show', 'I'),
#   ('me', 'I'),
#   ('evolve', 'N')],
#  [('Temple', 'N')],
#  [('Raxaul', 'N')],
#  [('Dhanalaxmi', 'N'), ('bank', 'N')],
#  [('Online', 'N'), ('offers', 'N')],
#  [('Gym', 'N'), ('charges', 'I'), ('?', 'I'), ('?', 'I')],
#  [('Old', 'N'), ('mobile', 'N'), ('phone', 'N')],
#  [('R', 'N'), ('u', 'N'), ('real', 'N'), ('?', 'I')],
#  [('Restarant', 'N')],
#  [('Petrol', 'N'), ('pump', 'I'), ('24/7', 'I'), ('one', 'I')],
#  [('Girl', 'N')],
#  [('give', 'I'),
#   ('me', 'I'),
#   ('some', 'I'),
#   ('call', 'N'),
#   ('girl', 'N'),
#   ('?', 'I')],
#  [('Want', 'I'), ('to', 'I'), ('buy', 'I'), ('EMI', 'I'), ('laptop', 'N')],
#  [('I', 'I'),
#   ('want', 'I'),
#   ('to', 'I'),
#   ('get', 'I'),
#   ('some', 'I'),
#   ('good', 'I'),
#   ('textbook', 'N'),
#   ('shops', 'N')],
#  [('Nearby', 'I'), ('Gym', 'N')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Bokajan', 'N')],
#  [('Resturant', 'N')],
#  [('Thanq', 'N')],
#  [('Cab', 'N')],
#  [('My', 'N'), ('location', 'N')],
#  [('More', 'I'), ('Nearby', 'I'), (':', 'I'), ('photo', 'N'), ('studio', 'N')],
#  [('Putikhali', 'N'), ('post', 'N'), ('office', 'N')],
#  [('Rohtak', 'N')],
#  [('Can', 'I'),
#   ('you', 'I'),
#   ('tell', 'I'),
#   ('me', 'I'),
#   ('jewellery', 'N'),
#   ('making', 'I'),
#   ('class', 'N'),
#   ('near', 'I'),
#   ('pursaiwalkam', 'I'),
#   ('?', 'I')],
#  [('Car', 'N'), ('motor', 'N'), ('training', 'N'), ('school', 'N')],
#  [('Yoga', 'N'), ('class', 'N'), ('near', 'I'), ('jamaliya', 'I'), ('?', 'I')],
#  [('Mm', 'N'), ('market', 'N')],
#  [('Indian', 'N'), ('bank', 'N')],
#  [('Hand', 'I'), ('watch', 'N'), ('repairing', 'N'), ('shop', 'N')],
#  [('Any', 'I'), ('pharmacy', 'N'), ('near', 'I'), ('to', 'I'), ('me', 'I')],
#  [('High', 'N'), ('school', 'N')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Maphel', 'N'),
#   ('salon', 'N')],
#  [('Yes', 'N'), ('bank', 'N'), ('atm', 'N')],
#  [('Price', 'I'), ('of', 'I'), ('nutafy', 'N'), ('gc', 'N')],
#  [('Retina', 'I'),
#   ('treatment', 'I'),
#   ('eye', 'I'),
#   ('hospital', 'N'),
#   ('available', 'I'),
#   ('in', 'I'),
#   ('purulia', 'I')],
#  [('Best', 'I'), ('eye', 'N'), ('hospital', 'N')],
#  [('More', 'I'), ('Nearby', 'I'), (':', 'I'), ('Shooes', 'N'), ('shop', 'N')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Bikaner', 'N')],
#  [('Hair', 'N'), ('salon', 'N')],
#  [('Please', 'I'),
#   ('share', 'I'),
#   ('the', 'I'),
#   ('details', 'I'),
#   ('of', 'I'),
#   ('nearest', 'I'),
#   ('pnb', 'N'),
#   ('atm', 'N')],
#  [('Helmet', 'N'),
#   ('shop', 'N'),
#   ('I', 'I'),
#   ('am', 'I'),
#   ('asking', 'I'),
#   ('?', 'I')],
#  [('Pure', 'N'), ('veg', 'N'), ('restaurant', 'N')],
#  [('Pub', 'N')],
#  [('Leena', 'N'), ('Beauty', 'N'), ('Parlour', 'N'), ('Diphu', 'I')],
#  [('RUKMINI', 'N'), ('THEATER', 'N')],
#  [('Find', 'I'), ('my', 'I'), ('nearest', 'I'), ('restaurant', 'N')],
#  [('Avani', 'N'), ('Chaturvedi', 'N')],
#  [('Play', 'I'), ('area', 'N'), ('for', 'I'), ('kids', 'N')],
#  [('Always', 'N'), ('?', 'I'), ('?', 'I')],
#  [('Show', 'I'), ('atm', 'N')],
#  [('search', 'I'), ('dentist', 'N'), ('near', 'I'), ('by', 'I'), ('me', 'I')],
#  [('Indusind', 'I'),
#   ('atm', 'N'),
#   ('n.a', 'I'),
#   ('.', 'I'),
#   ('map', 'I'),
#   ('nhi', 'I'),
#   ('hai', 'I')],
#  [('any', 'I'), ('appointment', 'N')],
#  [('sry', 'N')],
#  [('Near', 'I'), ('railway', 'N'), ('station', 'N')],
#  [('Bank', 'N'), ('of', 'N'), ('india', 'N')],
#  [('So', 'N'), ('how', 'N')],
#  [('Saree', 'N'), ('shop', 'N')],
#  [('Sjsb', 'N'), ('atm', 'N')],
#  [('Where', 'I'), ('is', 'I'), ('salon', 'N')],
#  [('You', 'I'), ('tell', 'N'), ('only', 'N'), ('my', 'N'), ('answer', 'N')],
#  [('thanyou', 'N')],
#  [('ha', 'N'), ('ha', 'N')],
#  [('Civil', 'N'), ('line', 'N'), ('bareilly', 'N')],
#  [('restaurant', 'N')],
#  [('U', 'N')],
#  [('G', 'N'), ('b', 'N'), ('roda', 'N'), ('delhi', 'I')],
#  [('Ra', 'N')],
#  [('Done', 'N')],
#  [('Hotel', 'N'), ('aura', 'N'), ('is', 'I'), ('hare', 'I')],
#  [('Tiffin', 'N'), ('centre', 'N'), ('near', 'I'), ('me', 'I')],
#  [('Running', 'N'), ('saidpur', 'N')],
#  [('Jayamangalam', 'N'), ('in', 'I'), ('dhevathanapatti', 'I')],
#  [('Nail', 'N'),
#   ('art', 'N'),
#   ('studio', 'N'),
#   ('in', 'I'),
#   ('INOX', 'I'),
#   (',', 'I'),
#   ('FARIDABAD', 'I')],
#  [('Market', 'N')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Bus', 'N')],
#  [('Can', 'I'), ('u', 'N'), ('now', 'I')],
#  [('Try', 'N'), ('now', 'N')],
#  [('Royal', 'N'), ('chmist', 'N')],
#  [('Tanks', 'N')],
#  [('Bus', 'N'), ('stad', 'N'), ('ludhiana', 'I')],
#  [('Can', 'I'),
#   ('u', 'I'),
#   ('help', 'I'),
#   ('me', 'I'),
#   ('out', 'I'),
#   ('of', 'I'),
#   ('Vodafone', 'N'),
#   ('mini', 'N'),
#   ('store', 'N')],
#  [('mall', 'N')],
#  [('Professional', 'N'), ('courier', 'N')],
#  [('Which', 'N'),
#   ('country', 'N'),
#   ('u', 'N'),
#   ('belong', 'N'),
#   ('to', 'N'),
#   ('...', 'I'),
#   ('?', 'I'),
#   ('?', 'I')],
#  [('where', 'I'), ('is', 'I'), ('beer', 'N'), ('shop', 'N')],
#  [('Andhara', 'N'), ('bank', 'N'), ('silvassa', 'I')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('atm', 'N')],
#  [('Jeckquain', 'N'), ('fandadish', 'N')],
#  [('Can', 'I'),
#   (',', 'I'),
#   ('you', 'I'),
#   ('find', 'I'),
#   ('canara', 'N'),
#   ('bank', 'N'),
#   ('atm', 'N'),
#   ('near', 'I'),
#   ('me', 'I'),
#   ('?', 'I')],
#  [('Shopping', 'N'), ('mall', 'N')],
#  [('Near', 'I'), ('petrol', 'N'), ('bunk', 'N')],
#  [('Nearby', 'I'), ('petrol', 'N'), ('pump', 'N')],
#  [('Ur', 'N'), ('good', 'N'), ('name', 'N')],
#  [('More', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('net', 'N'),
#   ('cafe', 'N'),
#   ('near', 'N'),
#   ('me', 'N')],
#  [('Sorry', 'I'),
#   ('...', 'I'),
#   ('.for', 'I'),
#   ('thumb..thts', 'I'),
#   ('my', 'I'),
#   ('touch', 'I'),
#   ('pad', 'N'),
#   ('problem', 'I')],
#  [('Chirag', 'N'), ('movoiya', 'N')],
#  [('Byeee', 'N')],
#  [('Karwar', 'N')],
#  [('Madhani', 'N')],
#  [('Warangal', 'N'), ('nayeemnagar', 'N')],
#  [('Thts', 'I'),
#   ('amezing', 'I'),
#   ('...', 'I'),
#   ('.', 'I'),
#   ('thnx', 'I'),
#   ('for', 'I'),
#   ('help', 'I'),
#   ('.', 'I'),
#   ('Thnx', 'I'),
#   ('samsung', 'I'),
#   ('..shilpa', 'I')],
#  [('Thats', 'N'), ('nice', 'N')],
#  [('My', 'I'),
#   ('location', 'I'),
#   ('jindal', 'N'),
#   ('Hospital', 'N'),
#   ('m.t.hisar', 'I')],
#  [('Othian', 'N')],
#  [('Cjufu', 'N')],
#  [('Samsung', 'N'), ('care', 'N'), ('near', 'I'), ('by', 'I'), ('me', 'I')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Ateli', 'N'),
#   ('mandi', 'N')],
#  [('Near', 'I'), ('by', 'I'), ('restaurant', 'N')],
#  [('I', 'I'), ("'m", 'I'), ('an', 'I'), ('army', 'N'), ('person', 'N')],
#  [('yr', 'I'),
#   ('aapka', 'I'),
#   ('phone', 'I'),
#   ('no', 'I'),
#   ('mil', 'N'),
#   ('skta', 'N'),
#   ('h', 'I')],
#  [('Nagapda', 'I'), ('neary', 'N'), ('atm', 'N')],
#  [('I', 'I'), ('want', 'I'), ('coat', 'N'), ('leg', 'N')],
#  [('Bank', 'N'),
#   ('of', 'N'),
#   ('baroda', 'N'),
#   ('branch', 'I'),
#   ('in', 'I'),
#   ('rk', 'I'),
#   ('colony', 'I')],
#  [('Maksudra', 'N'), ('Ludhiana', 'I'), ('Punjab', 'I')],
#  [('Food', 'N'), ('restaurants', 'N')],
#  [('Thats', 'I'), ('not', 'I'), ('my', 'N'), ('address', 'N')],
#  [('तु', 'I'), ('rhn', 'N'), ('देह', 'I')],
#  [('Thnkuu', 'N')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Amet', 'N')],
#  [('Jensen', 'N'), ('salon', 'N')],
#  [('Buttt', 'N'), ('nice', 'N')],
#  [('Mobile', 'N'), ('gallery', 'N')],
#  [('Paradeep', 'N')],
#  [('Tell', 'I'),
#   ('me', 'I'),
#   ('the', 'I'),
#   ('price', 'I'),
#   ('of', 'I'),
#   ('Nutrafy', 'N')],
#  [('More', 'I'), ('Nearby', 'I'), (':', 'I'), ('bike', 'N'), ('shop', 'N')],
#  [('Pijja', 'N'), ('hat', 'N')],
#  [('Swimming', 'N'), ('pool', 'N')],
#  [('Cheap', 'I'), ('girls', 'N')],
#  [('Kalimath', 'N'), ('jabalpur', 'N')],
#  [('Liquor', 'N'), ('shop', 'N')],
#  [('Sai', 'I'), ('Durga', 'N'), ('nager', 'N')],
#  [('Maaoori', 'N')],
#  [('I', 'I'),
#   ('want', 'I'),
#   ('phone', 'I'),
#   ('number', 'I'),
#   ('of', 'I'),
#   ('samalkot', 'I'),
#   ('jn', 'N'),
#   ('railway', 'N'),
#   ('station', 'N')],
#  [('Any', 'I'), ('kvb', 'N'), ('bank', 'N'), ('on', 'I'), ('neat', 'I')],
#  [('At', 'I'), ('churu', 'N')],
#  [('You', 'N'), ('from', 'N')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Nearest', 'N')],
#  [('Non', 'I'), ('veg', 'N'), ('restaurant', 'N'), ('?', 'I')],
#  [('Restaurant', 'N'),
#   ('nearby', 'I'),
#   ('station', 'I'),
#   ('road', 'I'),
#   ('305001', 'I')],
#  [('What', 'I'),
#   ('is', 'I'),
#   ('the', 'I'),
#   ('reting', 'N'),
#   ('of', 'I'),
#   ('doctor', 'N'),
#   ('randerwala', 'N')],
#  [('can', 'I'),
#   ('u', 'I'),
#   ('tell', 'I'),
#   ('nearest', 'I'),
#   ('restaurant', 'N')],
#  [('Saloon', 'N'), ('shops', 'N'), ('near', 'I'), ('me', 'I')],
#  [('Patanjli', 'N'), ('store', 'N')],
#  [('For', 'I'), ('women', 'N')],
#  [('Mysore', 'N')],
#  [('porn', 'N'), ('hub', 'N')],
#  [('How', 'I'), ('much', 'I'), ('hair', 'N'), ('treatment', 'N')],
#  [('MI', 'N'), ('service', 'N'), ('centre', 'N')],
#  [('Girls', 'N'), ('hostel', 'N')],
#  [('State', 'N'), ('bank', 'N')],
#  [('Parking', 'N'),
#   ('near', 'I'),
#   ('vinkar', 'I'),
#   ('sabhagruh', 'I'),
#   ('padmavati', 'I'),
#   ('pune', 'I')],
#  [('SAHABUL', 'N')],
#  [('More', 'I'), ('Nearby', 'I'), (':', 'I'), ('spa', 'N')],
#  [('Nearby', 'I'), ('sin', 'N'), ('ATM', 'N')],
#  [('Your', 'N'), ('location', 'N')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Bhagwant', 'N'),
#   ('nagar', 'N')],
#  [('More', 'I'), ('Nearby', 'I'), (':', 'I'), ('cake', 'N'), ('shop', 'N')],
#  [('Pest', 'N'), ('control', 'N'), ('services', 'N')],
#  [('More', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('jagdamba', 'N'),
#   ('waterpark', 'N')],
#  [('Hello', 'N'), ('abhishek', 'N')],
#  [('Kukatpalli', 'N'), ('metro', 'N')],
#  [('Where', 'I'), ('this', 'I'), ('place', 'N')],
#  [('Can', 'I'), ('i', 'I'), ('kiss', 'I'), ('u', 'N'), ('?', 'I')],
#  [('atm', 'N')],
#  [('veg', 'N'), ('restaurant', 'N')],
#  [('5Motijhil', 'I'), ('Syam', 'N'), ('cinema', 'N'), ('hall', 'N')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'N'),
#   ('Nearby', 'N'),
#   (':', 'I'),
#   ('Gyms', 'N'),
#   ('nearby', 'N')],
#  [('Ramapuram', 'N')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Temple', 'N')],
#  [('More', 'I'), ('Nearby', 'I'), (':', 'I'), ('resturant', 'N')],
#  [('Piza', 'N')],
#  [('Petrol', 'N')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Fru', 'N')],
#  [('Escort', 'N'), ('service', 'N'), ('in', 'I'), ('chandigarh', 'I')],
#  [('homo', 'N'), ('babu', 'N')],
#  [('N', 'N'), ('min', 'N'), ('price', 'I')],
#  [('All', 'I'), ('atm', 'N'), ('are', 'I'), ('close', 'I')],
#  [('Where', 'I'), ('is', 'I'), ('call', 'N'), ('girl', 'N')],
#  [('What', 'I'),
#   ('is', 'I'),
#   ('fetching', 'N'),
#   ('location', 'I'),
#   ('.', 'I')],
#  [('Why', 'I'),
#   ('I', 'I'),
#   ('share', 'I'),
#   ('my', 'N'),
#   ('location', 'N'),
#   ('to', 'N'),
#   ('you', 'I'),
#   ('.', 'I')],
#  [('Nearby', 'I'), ('Petrol', 'N'), ('Pump', 'N')],
#  [('I', 'I'),
#   ('calling', 'N'),
#   ('you', 'I'),
#   ('give', 'I'),
#   ('me', 'I'),
#   ('your', 'I'),
#   ('mobile', 'I'),
#   ('phone', 'I'),
#   ('number', 'I'),
#   ('.', 'I')],
#  [('So', 'I'),
#   ('Abhishek', 'N'),
#   ('friend', 'I'),
#   (';', 'I'),
#   ('Where', 'I'),
#   ('you', 'I'),
#   ("'re", 'I'),
#   ('home', 'I'),
#   ('?', 'I')],
#  [('Vegetable', 'N')],
#  [('More', 'I'), ('Nearby', 'I'), (':', 'I'), ('yoga', 'N'), ('classes', 'N')],
#  [('resturant', 'N'), ('loyabad', 'N')],
#  [('loyabaad', 'N')],
#  [('Price', 'I'), ('of', 'I'), ('petrol', 'N')],
#  [('R', 'N'), ('u', 'N'), ('real', 'N')],
#  [('In', 'I'), ('vikaspuri', 'N')],
#  [('Alibag', 'N'), ('route', 'N')],
#  [('Reliance', 'N'), ('digital', 'N')],
#  [('Boy', 'N'), ('salon', 'N')],
#  [('Op', 'N')],
#  [('kon', 'N'), ('kon', 'N'), ('sa', 'I'), ('resturant', 'N')],
#  [('Hi', 'I'),
#   (',', 'I'),
#   ('Abhishek', 'I'),
#   ('any', 'I'),
#   ('kind', 'I'),
#   ('of', 'I'),
#   ('offer', 'I'),
#   ('this', 'I'),
#   ('Bangali', 'N'),
#   ('cinama', 'N'),
#   ('Hami', 'N')],
#  [('massage', 'N'), ('parlour', 'N'), ('?', 'I')],
#  [('More', 'I'), ('Nearby', 'I'), (':', 'I'), ('inox', 'N')],
#  [('Park', 'N'), ('Circus', 'N')],
#  [('Nearby', 'I'), ('restaurant', 'N')],
#  [('@', 'I'), ('WesleyClarkSr', 'N'), ('.', 'I')],
#  [('Hp', 'N'), ('gas', 'N'), ('agency', 'N')],
#  [('Let', 'I'),
#   ('me', 'I'),
#   ('know', 'I'),
#   ('helmet', 'N'),
#   ('shops', 'N'),
#   ('near', 'I'),
#   ('the', 'I'),
#   ('location', 'I'),
#   ('where', 'I'),
#   ('I', 'I'),
#   ('am', 'I'),
#   ('now', 'I'),
#   ('?', 'I')],
#  [('Couple', 'N'), ('spa', 'N')],
#  [('State', 'N'), ('bank', 'N'), ('of', 'N'), ('ATM', 'N')],
#  [('salon', 'N'), ('near', 'I'), ('me', 'I')],
#  [('@', 'I'), ('BorlongkiBey', 'I'), ('Samsung', 'N'), ('India', 'N')],
#  [('I', 'I'), ('am', 'I'), ('at', 'I'), ('station', 'N'), ('road', 'N')],
#  [('M', 'I'), ('now', 'I'), ('jlandhar', 'N')],
#  [('BGodar', 'N')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Best', 'N'),
#   ('night', 'N'),
#   ('club', 'N')],
#  [('Fruit', 'N'), ('market', 'N')],
#  [('movie', 'N'), ('theater', 'N')],
#  [('More', 'I'), ('Nearby', 'I'), (':', 'I'), ('bareilly', 'N')],
#  [('More', 'I'), ('Nearby', 'I'), (':', 'I'), ('Mobile', 'N'), ('shop', 'N')],
#  [('Woman', 'N')],
#  [('More', 'I'), ('Nearby', 'I'), (':', 'I'), ('restorent', 'N')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Courier', 'N'),
#   ('service', 'N')],
#  [('Ludhiana', 'N')],
#  [('Pattom', 'N')],
#  [('Movies', 'N'), ('time', 'N')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Adharcard', 'N'),
#   ('center', 'N')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Result', 'N')],
#  [('Adharcard', 'N'), ('centre', 'N')],
#  [('Udaipur', 'N')],
#  [('How', 'I'), ('far', 'I'), ('is', 'I'), ('birmies', 'N')],
#  [('Sbi', 'N'), ('atm', 'N'), ('near', 'I')],
#  [('Mangal', 'N'), ('karyalaya', 'N')],
#  [('Nearest', 'I'), ('nikon', 'N'), ('shop', 'N')],
#  [('Canara', 'I'), ('bank', 'N'), ('lourd', 'I'), ('nagar', 'I')],
#  [('For', 'I'), ('female', 'N')],
#  [('Ohkk', 'N')],
#  [('I', 'I'), ('just', 'I'), ('check', 'N'), ('no', 'I'), ('need', 'I')],
#  [('Nearby', 'I'),
#   ('Issue', 'I'),
#   ('Details', 'I'),
#   ('Issue', 'I'),
#   ('Details', 'I'),
#   (':', 'I'),
#   ('Jhunjhunu', 'I'),
#   ('hdfc', 'N'),
#   ('bank', 'N'),
#   ('call', 'N'),
#   ('no', 'I'),
#   ('.', 'I'),
#   ('find', 'I')],
#  [('Kfc', 'N')],
#  [('Not', 'I'), ('these', 'I'), ('hotels', 'N')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Satelite', 'N')],
#  [('What', 'I'), ('is', 'I'), ('this', 'N'), ('all', 'N')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Hospital', 'N')],
#  [('Computer', 'N')],
#  [('Hall', 'N'), ('us', 'N')],
#  [('Find', 'I'),
#   ('nearest', 'I'),
#   ('metro', 'N'),
#   ('station', 'N'),
#   ('of', 'N'),
#   ('maharaja', 'N'),
#   ('agrasen', 'I'),
#   ('college', 'I')],
#  [('Wrong', 'N')],
#  [('hotels', 'N')],
#  [('Haa', 'N')],
#  [('What', 'I'), ('is', 'I'), ('that', 'I'), ('formula', 'N'), ('?', 'I')],
#  [('Tell', 'I'),
#   ('me', 'I'),
#   ('the', 'I'),
#   ('CNG', 'N'),
#   ('pump', 'N'),
#   ('near', 'I'),
#   ('haridwar', 'I')],
#  [('CNG', 'N'), ('pump', 'N'), ('near', 'I'), ('haridwar', 'I')],
#  [('Hotel', 'I'), ('for', 'I'), ('food', 'N')],
#  [('I', 'I'), ('know', 'N')],
#  [('Call', 'I'), ('girls', 'N')],
#  [('Hellp', 'N')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Airport', 'N')],
#  [('Any', 'I'), ('information', 'N')],
#  [('Near', 'I'), ('by', 'I'), ('oyo', 'N'), ('rooms', 'N')],
#  [('How', 'I'),
#   ('could', 'I'),
#   ('I', 'I'),
#   ('rectify', 'N'),
#   ('my', 'N'),
#   ('location', 'N')],
#  [('More', 'I'), ('Nearby', 'I'), (':', 'I'), ('school', 'N')],
#  [('Please', 'I'),
#   ('tell', 'I'),
#   ('me', 'I'),
#   ('medical', 'N'),
#   ('store', 'N'),
#   ('nearest', 'I')],
#  [('Ambaji', 'N'), ('medical', 'N')],
#  [('thnku', 'N')],
#  [('Ballabgarh', 'N')],
#  [('More', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('child', 'N'),
#   ('hospital', 'N')],
#  [('Mall', 'N')],
#  [('Kalpana', 'N'),
#   ('Studio', 'N'),
#   ('and', 'I'),
#   ('Communications', 'N'),
#   ('Diphu', 'I')],
#  [('Hiiii', 'N'), ('shilpa', 'N')],
#  [('aayurveda', 'N'), ('massage', 'N'), ('center', 'N')],
#  [('Prasando', 'N')],
#  [('fuck', 'N')],
#  [('Sex', 'N')],
#  [('playfore', 'N'), ('sex', 'N')],
#  [('OK', 'I'),
#   ('bye', 'I'),
#   ('Shilpa', 'N'),
#   ('see', 'I'),
#   ('u', 'I'),
#   ('soon', 'I')],
#  [('CNG', 'N'), ('STATION', 'N')],
#  [('Vijay', 'N'), ('sales', 'N')],
#  [('Stupid', 'N')],
#  [('OK', 'N'), ('good', 'N')],
#  [('tatto', 'N'), ('centrr', 'N')],
#  [('A', 'I'), ('stationary', 'N'), ('shop', 'N')],
#  [('tell', 'N'), ('your', 'N'), ('age', 'N')],
#  [('Secndrabad', 'N')],
#  [('Search', 'I'),
#   ('Again', 'I'),
#   ('Nearby', 'I'),
#   ('Nearby', 'I'),
#   (':', 'I'),
#   ('Instiute', 'N')],
#  [('Kamathipura', 'N')],
#  [('Bay', 'N')],
#  [('Is', 'I'), ('this', 'I'), ('computer', 'N'), ('or', 'I'), ('human', 'N')],
#  [('Oh', 'N'), ('really', 'N')],
#  [('call', 'I'), ('girl', 'N')],
#  [('Near', 'I'), ('by', 'I'), ('slippers', 'N'), ('shop', 'N')],
#  [('Katwa', 'N')],
#  [('Call', 'N'), ('me', 'N')],
#  [('tatto', 'N'), ('centre', 'N')],
#  [('CNG', 'N'), ('pump', 'N')],
#  [('State', 'N'), ('bank', 'N'), ('of', 'N'), ('India', 'N')],
#  [('Malegao', 'N'), ('cng', 'N')],
#  [('Noo', 'I'),
#   ('need', 'I'),
#   ('i', 'I'),
#   ('work', 'I'),
#   ('in', 'I'),
#   ('bank', 'N')],
#  [('Cng', 'N'), ('pomp', 'N')],
#  [('Jaipur', 'N'), ('junction', 'N')],
#  [('Chirag', 'I'), ('movliya', 'I'), ('how', 'I'), ('is', 'I'), ('thai', 'N')],
#  [('Chickkaballapur', 'N')],
#  [('Oe', 'N'), ('vai', 'N')],
#  [('Any', 'I'),
#   ('ice', 'N'),
#   ('cream', 'N'),
#   ('shop', 'N'),
#   ('is', 'I'),
#   ('there', 'I')],
#  ...]

# %%
import nltk
def post_tag(docs):
    data = []
    for i, doc in enumerate(docs):

        # Obtain the list of tokens in the document
        tokens = [t for t, label in doc]

        # Perform POS tagging
        tagged = nltk.pos_tag(tokens)

        # Take the word, POS tag, and its label
        data.append([(w, pos, label) for (w, label), (word, pos) in zip(doc, tagged)])
    return data

# %%
data = post_tag(docs)

# %%
def is_nearest(x):
    if ('near' in x):
        return True
    return False

def word2features(doc, i):
    word = doc[i][0]
    postag = doc[i][1]
    
    # Common features for all words
    features = [
        'bias',
        'word.lower=' + word.lower(),
        'word[-3:]=' + word[-3:],
        'word[-2:]=' + word[-2:],
        'word.isupper=%s' % word.isupper(),
        'word.istitle=%s' % word.istitle(),
        'word.isdigit=%s' % word.isdigit(),
        'postag=' + postag
    ]
    
    # Features for words that are not
    # at the beginning of a document
    if i > 0:
        word1 = doc[i-1][0]
        postag1 = doc[i-1][1]
        features.extend([
            '-1:word.lower=' + word1.lower(),
            '-1:word.istitle=%s' % word1.istitle(),
            '-1:word.isupper=%s' % word1.isupper(),
            '-1:word.isdigit=%s' % word1.isdigit(),
            '-1:postag=' + postag1,
            '-1:is_near=' + str(bool('near' in word1)),
            '-1:is_close=' + str(bool('close' in word1))
            
        ])
    else:
        # Indicate that it is the 'beginning of a document'
        features.append('BOS')

    # Features for words that are not
    # at the end of a document
    if i < len(doc)-1:
        word1 = doc[i+1][0]
        postag1 = doc[i+1][1]
        features.extend([
            '+1:word.lower=' + word1.lower(),
            '+1:word.istitle=%s' % word1.istitle(),
            '+1:word.isupper=%s' % word1.isupper(),
            '+1:word.isdigit=%s' % word1.isdigit(),
            '+1:postag=' + postag1
            #'+1:is_in_dict='+str(bool(lemmatizer.lemmatize(word1) in entity_dictionary_unigram_lemmas))
        ])
    else:
        # Indicate that it is the 'end of a document'
        features.append('EOS')

    return features

# %%
from sklearn.model_selection import train_test_split

# A function for extracting features in documents
def extract_features(doc):
    return [word2features(doc, i) for i in range(len(doc))]

# A function fo generating the list of labels for each document
def get_labels(doc):
    return [label for (token, postag, label) in doc]

X = [extract_features(doc) for doc in data]
y = [get_labels(doc) for doc in data]

X_train = X[:train_len]
y_train = y[:train_len]

X_test = X[train_len:]
y_test = y[train_len:]

# %%
len(X_train)
# Out:
# 14000

# %%
import pycrfsuite

def train_metrics():
    tagger = pycrfsuite.Tagger()
    tagger.open(model_name)

    y_pred = [tagger.tag(xseq) for xseq in X_train]
    
    
    import numpy as np
    from sklearn.metrics import classification_report

    # Create a mapping of labels to indices
    labels = {"N": 1, "I": 0}
    print(len(y_pred))
    # Convert the sequences of tags into a 1-dimensional array
    predictions = np.array([labels[tag] for row in y_pred for tag in row])
    truths = np.array([labels[tag] for row in y_train for tag in row])

    # Print out the classification report
    print('train', classification_report(
        truths, predictions,
        target_names=["I", "N"]))

    
    return classification_report(
        truths, predictions,
        target_names=["I", "N"])

    

def train_crf_model(c1=10, c2=10, max_iterations=1000):
    trainer = pycrfsuite.Trainer(verbose=False)


# Submit training data to the trainer
    for xseq, yseq in zip(X_train, y_train):
        trainer.append(xseq, yseq)

    # Set the parameters of the model
    trainer.set_params({
        # coefficient for L1 penalty
        'c1': c1,

        # coefficient for L2 penalty
        'c2': c2,  

        # maximum number of iterations
        'max_iterations': max_iterations,

        # whether to include transitions that
        # are possible, but not observed
        'feature.possible_transitions': True
    })

    # Provide a file name as a parameter to the train function, such that
    # the model will be saved to the file when training is finished
    trainer.train(model_name)
    
    tagger = pycrfsuite.Tagger()
    tagger.open(model_name)

    y_pred = [tagger.tag(xseq) for xseq in X_test]
    

    for x, y in zip(y_pred[i], [x[1].split("=")[1] for x in X_test[i]]):
        #print("%s (%s)" % (y, x))
        pass
    
    import numpy as np
    from sklearn.metrics import classification_report

    # Create a mapping of labels to indices
    labels = {"N": 1, "I": 0}
    print(len(y_pred))
    # Convert the sequences of tags into a 1-dimensional array
    predictions = np.array([labels[tag] for row in y_pred for tag in row])
    truths = np.array([labels[tag] for row in y_test for tag in row])

    # Print out the classification report
    print(classification_report(
        truths, predictions,
        target_names=["I", "N"]))
    
    return classification_report(
        truths, predictions,
        target_names=["I", "N"])

# %%
result_analysis = {'c1': [], 'c2': [], 'result': [], 'max_iterations': [], 'train/test': [], 'model_name': []}

for i in range(0,15,5):
    for j in range(0,15,5):
        for k in range(1000,10000,1000):
            print('C1: ', i, 'C2: ', j, 'MAX_ITERS:', k)
            model_name = '/home/pratik/crf_model/pos' + str(i) + str(j) + str(k) + '.model'
            result = train_crf_model(c1=i, c2=j, max_iterations=k)
            result_analysis['c1'].append(i)
            result_analysis['c2'].append(j)
            result_analysis['result'].append(result)
            result_analysis['max_iterations'].append(k)
            result_analysis['train/test'].append('test')
            result_analysis['model_name'].append(model_name)
            result = train_metrics()
            result_analysis['c1'].append(i)
            result_analysis['c2'].append(j)
            result_analysis['result'].append(result)
            result_analysis['max_iterations'].append(k)
            result_analysis['train/test'].append('train')
            result_analysis['model_name'].append(model_name)
            print('--------------------------')
# Out:
# C1:  0 C2:  0 MAX_ITERS: 1000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.88      0.90      7148
#           N       0.83      0.88      0.85      4681
#
# avg / total       0.88      0.88      0.88     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.97      0.98      0.97     29866
#           N       0.97      0.96      0.97     24231
#
# avg / total       0.97      0.97      0.97     54097
#
# --------------------------
# C1:  0 C2:  0 MAX_ITERS: 2000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.87      0.89      7148
#           N       0.82      0.88      0.85      4681
#
# avg / total       0.88      0.87      0.87     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.97      0.97      0.97     29866
#           N       0.97      0.96      0.97     24231
#
# avg / total       0.97      0.97      0.97     54097
#
# --------------------------
# C1:  0 C2:  0 MAX_ITERS: 3000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.91      0.87      0.89      7148
#           N       0.81      0.87      0.84      4681
#
# avg / total       0.87      0.87      0.87     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.97      0.97      0.97     29866
#           N       0.97      0.96      0.97     24231
#
# avg / total       0.97      0.97      0.97     54097
#
# --------------------------
# C1:  0 C2:  0 MAX_ITERS: 4000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.91      0.87      0.89      7148
#           N       0.81      0.87      0.84      4681
#
# avg / total       0.87      0.87      0.87     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.97      0.97      0.97     29866
#           N       0.97      0.96      0.97     24231
#
# avg / total       0.97      0.97      0.97     54097
#
# --------------------------
# C1:  0 C2:  0 MAX_ITERS: 5000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.91      0.87      0.89      7148
#           N       0.81      0.87      0.84      4681
#
# avg / total       0.87      0.87      0.87     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.97      0.97      0.97     29866
#           N       0.97      0.96      0.97     24231
#
# avg / total       0.97      0.97      0.97     54097
#
# --------------------------
# C1:  0 C2:  0 MAX_ITERS: 6000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.91      0.87      0.89      7148
#           N       0.81      0.87      0.84      4681
#
# avg / total       0.87      0.87      0.87     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.97      0.97      0.97     29866
#           N       0.97      0.96      0.97     24231
#
# avg / total       0.97      0.97      0.97     54097
#
# --------------------------
# C1:  0 C2:  0 MAX_ITERS: 7000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.91      0.87      0.89      7148
#           N       0.81      0.87      0.84      4681
#
# avg / total       0.87      0.87      0.87     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.97      0.97      0.97     29866
#           N       0.97      0.96      0.97     24231
#
# avg / total       0.97      0.97      0.97     54097
#
# --------------------------
# C1:  0 C2:  0 MAX_ITERS: 8000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.91      0.87      0.89      7148
#           N       0.81      0.87      0.84      4681
#
# avg / total       0.87      0.87      0.87     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.97      0.97      0.97     29866
#           N       0.97      0.96      0.97     24231
#
# avg / total       0.97      0.97      0.97     54097
#
# --------------------------
# C1:  0 C2:  0 MAX_ITERS: 9000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.91      0.87      0.89      7148
#           N       0.81      0.87      0.84      4681
#
# avg / total       0.87      0.87      0.87     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.97      0.97      0.97     29866
#           N       0.97      0.96      0.97     24231
#
# avg / total       0.97      0.97      0.97     54097
#
# --------------------------
# C1:  0 C2:  5 MAX_ITERS: 1000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.93      0.89      0.91      7148
#           N       0.84      0.89      0.87      4681
#
# avg / total       0.89      0.89      0.89     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.92      0.90      0.91     29866
#           N       0.88      0.90      0.89     24231
#
# avg / total       0.90      0.90      0.90     54097
#
# --------------------------
# C1:  0 C2:  5 MAX_ITERS: 2000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.93      0.89      0.91      7148
#           N       0.84      0.89      0.87      4681
#
# avg / total       0.89      0.89      0.89     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.92      0.90      0.91     29866
#           N       0.88      0.90      0.89     24231
#
# avg / total       0.90      0.90      0.90     54097
#
# --------------------------
# C1:  0 C2:  5 MAX_ITERS: 3000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.93      0.89      0.91      7148
#           N       0.84      0.89      0.87      4681
#
# avg / total       0.89      0.89      0.89     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.92      0.90      0.91     29866
#           N       0.88      0.90      0.89     24231
#
# avg / total       0.90      0.90      0.90     54097
#
# --------------------------
# C1:  0 C2:  5 MAX_ITERS: 4000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.93      0.89      0.91      7148
#           N       0.84      0.89      0.87      4681
#
# avg / total       0.89      0.89      0.89     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.92      0.90      0.91     29866
#           N       0.88      0.90      0.89     24231
#
# avg / total       0.90      0.90      0.90     54097
#
# --------------------------
# C1:  0 C2:  5 MAX_ITERS: 5000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.93      0.89      0.91      7148
#           N       0.84      0.89      0.87      4681
#
# avg / total       0.89      0.89      0.89     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.92      0.90      0.91     29866
#           N       0.88      0.90      0.89     24231
#
# avg / total       0.90      0.90      0.90     54097
#
# --------------------------
# C1:  0 C2:  5 MAX_ITERS: 6000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.93      0.89      0.91      7148
#           N       0.84      0.89      0.87      4681
#
# avg / total       0.89      0.89      0.89     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.92      0.90      0.91     29866
#           N       0.88      0.90      0.89     24231
#
# avg / total       0.90      0.90      0.90     54097
#
# --------------------------
# C1:  0 C2:  5 MAX_ITERS: 7000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.93      0.89      0.91      7148
#           N       0.84      0.89      0.87      4681
#
# avg / total       0.89      0.89      0.89     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.92      0.90      0.91     29866
#           N       0.88      0.90      0.89     24231
#
# avg / total       0.90      0.90      0.90     54097
#
# --------------------------
# C1:  0 C2:  5 MAX_ITERS: 8000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.93      0.89      0.91      7148
#           N       0.84      0.89      0.87      4681
#
# avg / total       0.89      0.89      0.89     11829
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.92      0.90      0.91     29866
#           N       0.88      0.90      0.89     24231
#
# avg / total       0.90      0.90      0.90     54097
#
# --------------------------
# C1:  0 C2:  5 MAX_ITERS: 9000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.93      0.89      0.91      7148
#           N       0.84      0.89      0.87      4681
#
# avg / total       0.89      0.89      0.89     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.92      0.90      0.91     29866
#           N       0.88      0.90      0.89     24231
#
# avg / total       0.90      0.90      0.90     54097
#
# --------------------------
# C1:  0 C2:  10 MAX_ITERS: 1000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.89      0.91      7148
#           N       0.84      0.89      0.86      4681
#
# avg / total       0.89      0.89      0.89     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.91      0.90      0.90     29866
#           N       0.87      0.89      0.88     24231
#
# avg / total       0.90      0.90      0.90     54097
#
# --------------------------
# C1:  0 C2:  10 MAX_ITERS: 2000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.89      0.91      7148
#           N       0.84      0.89      0.86      4681
#
# avg / total       0.89      0.89      0.89     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.91      0.90      0.90     29866
#           N       0.87      0.89      0.88     24231
#
# avg / total       0.90      0.90      0.90     54097
#
# --------------------------
# C1:  0 C2:  10 MAX_ITERS: 3000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.89      0.91      7148
#           N       0.84      0.89      0.86      4681
#
# avg / total       0.89      0.89      0.89     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.91      0.90      0.90     29866
#           N       0.87      0.89      0.88     24231
#
# avg / total       0.90      0.90      0.90     54097
#
# --------------------------
# C1:  0 C2:  10 MAX_ITERS: 4000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.89      0.91      7148
#           N       0.84      0.89      0.86      4681
#
# avg / total       0.89      0.89      0.89     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.91      0.90      0.90     29866
#           N       0.87      0.89      0.88     24231
#
# avg / total       0.90      0.90      0.90     54097
#
# --------------------------
# C1:  0 C2:  10 MAX_ITERS: 5000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.89      0.91      7148
#           N       0.84      0.89      0.86      4681
#
# avg / total       0.89      0.89      0.89     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.91      0.90      0.90     29866
#           N       0.87      0.89      0.88     24231
#
# avg / total       0.90      0.90      0.90     54097
#
# --------------------------
# C1:  0 C2:  10 MAX_ITERS: 6000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.89      0.91      7148
#           N       0.84      0.89      0.86      4681
#
# avg / total       0.89      0.89      0.89     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.91      0.90      0.90     29866
#           N       0.87      0.89      0.88     24231
#
# avg / total       0.90      0.90      0.90     54097
#
# --------------------------
# C1:  0 C2:  10 MAX_ITERS: 7000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.89      0.91      7148
#           N       0.84      0.89      0.86      4681
#
# avg / total       0.89      0.89      0.89     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.91      0.90      0.90     29866
#           N       0.87      0.89      0.88     24231
#
# avg / total       0.90      0.90      0.90     54097
#
# --------------------------
# C1:  0 C2:  10 MAX_ITERS: 8000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.89      0.91      7148
#           N       0.84      0.89      0.86      4681
#
# avg / total       0.89      0.89      0.89     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.91      0.90      0.90     29866
#           N       0.87      0.89      0.88     24231
#
# avg / total       0.90      0.90      0.90     54097
#
# --------------------------
# C1:  0 C2:  10 MAX_ITERS: 9000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.89      0.91      7148
#           N       0.84      0.89      0.86      4681
#
# avg / total       0.89      0.89      0.89     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.91      0.90      0.90     29866
#           N       0.87      0.89      0.88     24231
#
# avg / total       0.90      0.90      0.90     54097
#
# --------------------------
# C1:  5 C2:  0 MAX_ITERS: 1000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.88      0.90      7148
#           N       0.83      0.89      0.86      4681
#
# avg / total       0.89      0.89      0.89     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.91      0.89      0.90     29866
#           N       0.87      0.89      0.88     24231
#
# avg / total       0.89      0.89      0.89     54097
#
# --------------------------
# C1:  5 C2:  0 MAX_ITERS: 2000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.88      0.90      7148
#           N       0.83      0.89      0.86      4681
#
# avg / total       0.89      0.89      0.89     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.91      0.89      0.90     29866
#           N       0.87      0.89      0.88     24231
#
# avg / total       0.89      0.89      0.89     54097
#
# --------------------------
# C1:  5 C2:  0 MAX_ITERS: 3000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.88      0.90      7148
#           N       0.83      0.89      0.86      4681
#
# avg / total       0.89      0.89      0.89     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.91      0.89      0.90     29866
#           N       0.87      0.89      0.88     24231
#
# avg / total       0.89      0.89      0.89     54097
#
# --------------------------
# C1:  5 C2:  0 MAX_ITERS: 4000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.88      0.90      7148
#           N       0.83      0.89      0.86      4681
#
# avg / total       0.89      0.89      0.89     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.91      0.89      0.90     29866
#           N       0.87      0.89      0.88     24231
#
# avg / total       0.89      0.89      0.89     54097
#
# --------------------------
# C1:  5 C2:  0 MAX_ITERS: 5000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.88      0.90      7148
#           N       0.83      0.89      0.86      4681
#
# avg / total       0.89      0.89      0.89     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.91      0.89      0.90     29866
#           N       0.87      0.89      0.88     24231
#
# avg / total       0.89      0.89      0.89     54097
#
# --------------------------
# C1:  5 C2:  0 MAX_ITERS: 6000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.88      0.90      7148
#           N       0.83      0.89      0.86      4681
#
# avg / total       0.89      0.89      0.89     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.91      0.89      0.90     29866
#           N       0.87      0.89      0.88     24231
#
# avg / total       0.89      0.89      0.89     54097
#
# --------------------------
# C1:  5 C2:  0 MAX_ITERS: 7000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.88      0.90      7148
#           N       0.83      0.89      0.86      4681
#
# avg / total       0.89      0.89      0.89     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.91      0.89      0.90     29866
#           N       0.87      0.89      0.88     24231
#
# avg / total       0.89      0.89      0.89     54097
#
# --------------------------
# C1:  5 C2:  0 MAX_ITERS: 8000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.88      0.90      7148
#           N       0.83      0.89      0.86      4681
#
# avg / total       0.89      0.89      0.89     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.91      0.89      0.90     29866
#           N       0.87      0.89      0.88     24231
#
# avg / total       0.89      0.89      0.89     54097
#
# --------------------------
# C1:  5 C2:  0 MAX_ITERS: 9000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.88      0.90      7148
#           N       0.83      0.89      0.86      4681
#
# avg / total       0.89      0.89      0.89     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.91      0.89      0.90     29866
#           N       0.87      0.89      0.88     24231
#
# avg / total       0.89      0.89      0.89     54097
#
# --------------------------
# C1:  5 C2:  5 MAX_ITERS: 1000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.88      0.90      7148
#           N       0.83      0.88      0.86      4681
#
# avg / total       0.89      0.88      0.88     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.90      0.89      0.89     29866
#           N       0.86      0.88      0.87     24231
#
# avg / total       0.88      0.88      0.88     54097
#
# --------------------------
# C1:  5 C2:  5 MAX_ITERS: 2000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.88      0.90      7148
#           N       0.83      0.88      0.86      4681
#
# avg / total       0.89      0.88      0.88     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.90      0.89      0.89     29866
#           N       0.86      0.88      0.87     24231
#
# avg / total       0.88      0.88      0.88     54097
#
# --------------------------
# C1:  5 C2:  5 MAX_ITERS: 3000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.88      0.90      7148
#           N       0.83      0.88      0.86      4681
#
# avg / total       0.89      0.88      0.88     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.90      0.89      0.89     29866
#           N       0.86      0.88      0.87     24231
#
# avg / total       0.88      0.88      0.88     54097
#
# --------------------------
# C1:  5 C2:  5 MAX_ITERS: 4000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.88      0.90      7148
#           N       0.83      0.88      0.86      4681
#
# avg / total       0.89      0.88      0.88     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.90      0.89      0.89     29866
#           N       0.86      0.88      0.87     24231
#
# avg / total       0.88      0.88      0.88     54097
#
# --------------------------
# C1:  5 C2:  5 MAX_ITERS: 5000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.88      0.90      7148
#           N       0.83      0.88      0.86      4681
#
# avg / total       0.89      0.88      0.88     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.90      0.89      0.89     29866
#           N       0.86      0.88      0.87     24231
#
# avg / total       0.88      0.88      0.88     54097
#
# --------------------------
# C1:  5 C2:  5 MAX_ITERS: 6000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.88      0.90      7148
#           N       0.83      0.88      0.86      4681
#
# avg / total       0.89      0.88      0.88     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.90      0.89      0.89     29866
#           N       0.86      0.88      0.87     24231
#
# avg / total       0.88      0.88      0.88     54097
#
# --------------------------
# C1:  5 C2:  5 MAX_ITERS: 7000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.88      0.90      7148
#           N       0.83      0.88      0.86      4681
#
# avg / total       0.89      0.88      0.88     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.90      0.89      0.89     29866
#           N       0.86      0.88      0.87     24231
#
# avg / total       0.88      0.88      0.88     54097
#
# --------------------------
# C1:  5 C2:  5 MAX_ITERS: 8000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.88      0.90      7148
#           N       0.83      0.88      0.86      4681
#
# avg / total       0.89      0.88      0.88     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.90      0.89      0.89     29866
#           N       0.86      0.88      0.87     24231
#
# avg / total       0.88      0.88      0.88     54097
#
# --------------------------
# C1:  5 C2:  5 MAX_ITERS: 9000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.88      0.90      7148
#           N       0.83      0.88      0.86      4681
#
# avg / total       0.89      0.88      0.88     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.90      0.89      0.89     29866
#           N       0.86      0.88      0.87     24231
#
# avg / total       0.88      0.88      0.88     54097
#
# --------------------------
# C1:  5 C2:  10 MAX_ITERS: 1000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.88      0.90      7148
#           N       0.83      0.88      0.85      4681
#
# avg / total       0.88      0.88      0.88     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.90      0.88      0.89     29866
#           N       0.86      0.88      0.87     24231
#
# avg / total       0.88      0.88      0.88     54097
#
# --------------------------
# C1:  5 C2:  10 MAX_ITERS: 2000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.88      0.90      7148
#           N       0.83      0.88      0.85      4681
#
# avg / total       0.88      0.88      0.88     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.90      0.88      0.89     29866
#           N       0.86      0.88      0.87     24231
#
# avg / total       0.88      0.88      0.88     54097
#
# --------------------------
# C1:  5 C2:  10 MAX_ITERS: 3000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.88      0.90      7148
#           N       0.83      0.88      0.85      4681
#
# avg / total       0.88      0.88      0.88     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.90      0.88      0.89     29866
#           N       0.86      0.88      0.87     24231
#
# avg / total       0.88      0.88      0.88     54097
#
# --------------------------
# C1:  5 C2:  10 MAX_ITERS: 4000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.88      0.90      7148
#           N       0.83      0.88      0.85      4681
#
# avg / total       0.88      0.88      0.88     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.90      0.88      0.89     29866
#           N       0.86      0.88      0.87     24231
#
# avg / total       0.88      0.88      0.88     54097
#
# --------------------------
# C1:  5 C2:  10 MAX_ITERS: 5000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.88      0.90      7148
#           N       0.83      0.88      0.85      4681
#
# avg / total       0.88      0.88      0.88     11829
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.90      0.88      0.89     29866
#           N       0.86      0.88      0.87     24231
#
# avg / total       0.88      0.88      0.88     54097
#
# --------------------------
# C1:  5 C2:  10 MAX_ITERS: 6000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.88      0.90      7148
#           N       0.83      0.88      0.85      4681
#
# avg / total       0.88      0.88      0.88     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.90      0.88      0.89     29866
#           N       0.86      0.88      0.87     24231
#
# avg / total       0.88      0.88      0.88     54097
#
# --------------------------
# C1:  5 C2:  10 MAX_ITERS: 7000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.88      0.90      7148
#           N       0.83      0.88      0.85      4681
#
# avg / total       0.88      0.88      0.88     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.90      0.88      0.89     29866
#           N       0.86      0.88      0.87     24231
#
# avg / total       0.88      0.88      0.88     54097
#
# --------------------------
# C1:  5 C2:  10 MAX_ITERS: 8000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.88      0.90      7148
#           N       0.83      0.88      0.85      4681
#
# avg / total       0.88      0.88      0.88     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.90      0.88      0.89     29866
#           N       0.86      0.88      0.87     24231
#
# avg / total       0.88      0.88      0.88     54097
#
# --------------------------
# C1:  5 C2:  10 MAX_ITERS: 9000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.88      0.90      7148
#           N       0.83      0.88      0.85      4681
#
# avg / total       0.88      0.88      0.88     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.90      0.88      0.89     29866
#           N       0.86      0.88      0.87     24231
#
# avg / total       0.88      0.88      0.88     54097
#
# --------------------------
# C1:  10 C2:  0 MAX_ITERS: 1000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.88      0.90      7148
#           N       0.83      0.88      0.85      4681
#
# avg / total       0.88      0.88      0.88     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.90      0.88      0.89     29866
#           N       0.86      0.88      0.87     24231
#
# avg / total       0.88      0.88      0.88     54097
#
# --------------------------
# C1:  10 C2:  0 MAX_ITERS: 2000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.88      0.90      7148
#           N       0.83      0.88      0.85      4681
#
# avg / total       0.88      0.88      0.88     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.90      0.88      0.89     29866
#           N       0.86      0.88      0.87     24231
#
# avg / total       0.88      0.88      0.88     54097
#
# --------------------------
# C1:  10 C2:  0 MAX_ITERS: 3000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.88      0.90      7148
#           N       0.83      0.88      0.85      4681
#
# avg / total       0.88      0.88      0.88     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.90      0.88      0.89     29866
#           N       0.86      0.88      0.87     24231
#
# avg / total       0.88      0.88      0.88     54097
#
# --------------------------
# C1:  10 C2:  0 MAX_ITERS: 4000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.88      0.90      7148
#           N       0.83      0.88      0.85      4681
#
# avg / total       0.88      0.88      0.88     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.90      0.88      0.89     29866
#           N       0.86      0.88      0.87     24231
#
# avg / total       0.88      0.88      0.88     54097
#
# --------------------------
# C1:  10 C2:  0 MAX_ITERS: 5000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.88      0.90      7148
#           N       0.83      0.88      0.85      4681
#
# avg / total       0.88      0.88      0.88     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.90      0.88      0.89     29866
#           N       0.86      0.88      0.87     24231
#
# avg / total       0.88      0.88      0.88     54097
#
# --------------------------
# C1:  10 C2:  0 MAX_ITERS: 6000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.88      0.90      7148
#           N       0.83      0.88      0.85      4681
#
# avg / total       0.88      0.88      0.88     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.90      0.88      0.89     29866
#           N       0.86      0.88      0.87     24231
#
# avg / total       0.88      0.88      0.88     54097
#
# --------------------------
# C1:  10 C2:  0 MAX_ITERS: 7000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.88      0.90      7148
#           N       0.83      0.88      0.85      4681
#
# avg / total       0.88      0.88      0.88     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.90      0.88      0.89     29866
#           N       0.86      0.88      0.87     24231
#
# avg / total       0.88      0.88      0.88     54097
#
# --------------------------
# C1:  10 C2:  0 MAX_ITERS: 8000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.88      0.90      7148
#           N       0.83      0.88      0.85      4681
#
# avg / total       0.88      0.88      0.88     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.90      0.88      0.89     29866
#           N       0.86      0.88      0.87     24231
#
# avg / total       0.88      0.88      0.88     54097
#
# --------------------------
# C1:  10 C2:  0 MAX_ITERS: 9000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.88      0.90      7148
#           N       0.83      0.88      0.85      4681
#
# avg / total       0.88      0.88      0.88     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.90      0.88      0.89     29866
#           N       0.86      0.88      0.87     24231
#
# avg / total       0.88      0.88      0.88     54097
#
# --------------------------
# C1:  10 C2:  5 MAX_ITERS: 1000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.88      0.90      7148
#           N       0.83      0.88      0.85      4681
#
# avg / total       0.88      0.88      0.88     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.90      0.88      0.89     29866
#           N       0.85      0.88      0.86     24231
#
# avg / total       0.88      0.88      0.88     54097
#
# --------------------------
# C1:  10 C2:  5 MAX_ITERS: 2000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.88      0.90      7148
#           N       0.83      0.88      0.85      4681
#
# avg / total       0.88      0.88      0.88     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.90      0.88      0.89     29866
#           N       0.85      0.88      0.86     24231
#
# avg / total       0.88      0.88      0.88     54097
#
# --------------------------
# C1:  10 C2:  5 MAX_ITERS: 3000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.88      0.90      7148
#           N       0.83      0.88      0.85      4681
#
# avg / total       0.88      0.88      0.88     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.90      0.88      0.89     29866
#           N       0.85      0.88      0.86     24231
#
# avg / total       0.88      0.88      0.88     54097
#
# --------------------------
# C1:  10 C2:  5 MAX_ITERS: 4000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.88      0.90      7148
#           N       0.83      0.88      0.85      4681
#
# avg / total       0.88      0.88      0.88     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.90      0.88      0.89     29866
#           N       0.85      0.88      0.86     24231
#
# avg / total       0.88      0.88      0.88     54097
#
# --------------------------
# C1:  10 C2:  5 MAX_ITERS: 5000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.88      0.90      7148
#           N       0.83      0.88      0.85      4681
#
# avg / total       0.88      0.88      0.88     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.90      0.88      0.89     29866
#           N       0.85      0.88      0.86     24231
#
# avg / total       0.88      0.88      0.88     54097
#
# --------------------------
# C1:  10 C2:  5 MAX_ITERS: 6000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.88      0.90      7148
#           N       0.83      0.88      0.85      4681
#
# avg / total       0.88      0.88      0.88     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.90      0.88      0.89     29866
#           N       0.85      0.88      0.86     24231
#
# avg / total       0.88      0.88      0.88     54097
#
# --------------------------
# C1:  10 C2:  5 MAX_ITERS: 7000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.88      0.90      7148
#           N       0.83      0.88      0.85      4681
#
# avg / total       0.88      0.88      0.88     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.90      0.88      0.89     29866
#           N       0.85      0.88      0.86     24231
#
# avg / total       0.88      0.88      0.88     54097
#
# --------------------------
# C1:  10 C2:  5 MAX_ITERS: 8000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.88      0.90      7148
#           N       0.83      0.88      0.85      4681
#
# avg / total       0.88      0.88      0.88     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.90      0.88      0.89     29866
#           N       0.85      0.88      0.86     24231
#
# avg / total       0.88      0.88      0.88     54097
#
# --------------------------
# C1:  10 C2:  5 MAX_ITERS: 9000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.92      0.88      0.90      7148
#           N       0.83      0.88      0.85      4681
#
# avg / total       0.88      0.88      0.88     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.90      0.88      0.89     29866
#           N       0.85      0.88      0.86     24231
#
# avg / total       0.88      0.88      0.88     54097
#
# --------------------------
# C1:  10 C2:  10 MAX_ITERS: 1000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.91      0.88      0.90      7148
#           N       0.83      0.87      0.85      4681
#
# avg / total       0.88      0.88      0.88     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.90      0.88      0.89     29866
#           N       0.85      0.87      0.86     24231
#
# avg / total       0.88      0.87      0.87     54097
#
# --------------------------
# C1:  10 C2:  10 MAX_ITERS: 2000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.91      0.88      0.90      7148
#           N       0.83      0.87      0.85      4681
#
# avg / total       0.88      0.88      0.88     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.90      0.88      0.89     29866
#           N       0.85      0.87      0.86     24231
#
# avg / total       0.88      0.87      0.87     54097
#
# --------------------------
# C1:  10 C2:  10 MAX_ITERS: 3000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.91      0.88      0.90      7148
#           N       0.83      0.87      0.85      4681
#
# avg / total       0.88      0.88      0.88     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.90      0.88      0.89     29866
#           N       0.85      0.87      0.86     24231
#
# avg / total       0.88      0.87      0.87     54097
#
# --------------------------
# C1:  10 C2:  10 MAX_ITERS: 4000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.91      0.88      0.90      7148
#           N       0.83      0.87      0.85      4681
#
# avg / total       0.88      0.88      0.88     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.90      0.88      0.89     29866
#           N       0.85      0.87      0.86     24231
#
# avg / total       0.88      0.87      0.87     54097
#
# --------------------------
# C1:  10 C2:  10 MAX_ITERS: 5000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.91      0.88      0.90      7148
#           N       0.83      0.87      0.85      4681
#
# avg / total       0.88      0.88      0.88     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.90      0.88      0.89     29866
#           N       0.85      0.87      0.86     24231
#
# avg / total       0.88      0.87      0.87     54097
#
# --------------------------
# C1:  10 C2:  10 MAX_ITERS: 6000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.91      0.88      0.90      7148
#           N       0.83      0.87      0.85      4681
#
# avg / total       0.88      0.88      0.88     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.90      0.88      0.89     29866
#           N       0.85      0.87      0.86     24231
#
# avg / total       0.88      0.87      0.87     54097
#
# --------------------------
# C1:  10 C2:  10 MAX_ITERS: 7000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.91      0.88      0.90      7148
#           N       0.83      0.87      0.85      4681
#
# avg / total       0.88      0.88      0.88     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.90      0.88      0.89     29866
#           N       0.85      0.87      0.86     24231
#
# avg / total       0.88      0.87      0.87     54097
#
# --------------------------
# C1:  10 C2:  10 MAX_ITERS: 8000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.91      0.88      0.90      7148
#           N       0.83      0.87      0.85      4681
#
# avg / total       0.88      0.88      0.88     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.90      0.88      0.89     29866
#           N       0.85      0.87      0.86     24231
#
# avg / total       0.88      0.87      0.87     54097
#
# --------------------------
# C1:  10 C2:  10 MAX_ITERS: 9000
# 2623
#              precision    recall  f1-score   support
#
#           I       0.91      0.88      0.90      7148
#           N       0.83      0.87      0.85      4681
#
# avg / total       0.88      0.88      0.88     11829
#
# 14000
# train              precision    recall  f1-score   support
#
#           I       0.90      0.88      0.89     29866
#           N       0.85      0.87      0.86     24231
#
# avg / total       0.88      0.87      0.87     54097
#
# --------------------------

# %%
result_pandas = pd.DataFrame.from_dict(result_analysis)

# %%
result_pandas['Iprecision'] = result_pandas['result'].apply(lambda x : x.split()[5])
result_pandas['Irecall'] = result_pandas['result'].apply(lambda x : x.split()[6])
result_pandas['If_score'] = result_pandas['result'].apply(lambda x : x.split()[7])
result_pandas['Nprecision'] = result_pandas['result'].apply(lambda x : x.split()[10])
result_pandas['Nrecall'] = result_pandas['result'].apply(lambda x : x.split()[11])
result_pandas['Nf_score'] = result_pandas['result'].apply(lambda x : x.split()[12])
result_pandas['precision'] = result_pandas['result'].apply(lambda x : x.split()[17])
result_pandas['recall'] = result_pandas['result'].apply(lambda x : x.split()[18])
result_pandas['f_score'] = result_pandas['result'].apply(lambda x : x.split()[19])

# %%
result_pandas
# Out:
#      c1  c2  max_iterations                                model_name  \
# 0     0   0            1000    /home/pratik/crf_model/pos001000.model
# 1     0   0            1000    /home/pratik/crf_model/pos001000.model
# 2     0   0            2000    /home/pratik/crf_model/pos002000.model
# 3     0   0            2000    /home/pratik/crf_model/pos002000.model
# 4     0   0            3000    /home/pratik/crf_model/pos003000.model
# 5     0   0            3000    /home/pratik/crf_model/pos003000.model
# 6     0   0            4000    /home/pratik/crf_model/pos004000.model
# 7     0   0            4000    /home/pratik/crf_model/pos004000.model
# 8     0   0            5000    /home/pratik/crf_model/pos005000.model
# 9     0   0            5000    /home/pratik/crf_model/pos005000.model
# 10    0   0            6000    /home/pratik/crf_model/pos006000.model
# 11    0   0            6000    /home/pratik/crf_model/pos006000.model
# 12    0   0            7000    /home/pratik/crf_model/pos007000.model
# 13    0   0            7000    /home/pratik/crf_model/pos007000.model
# 14    0   0            8000    /home/pratik/crf_model/pos008000.model
# 15    0   0            8000    /home/pratik/crf_model/pos008000.model
# 16    0   0            9000    /home/pratik/crf_model/pos009000.model
# 17    0   0            9000    /home/pratik/crf_model/pos009000.model
# 18    0   5            1000    /home/pratik/crf_model/pos051000.model
# 19    0   5            1000    /home/pratik/crf_model/pos051000.model
# 20    0   5            2000    /home/pratik/crf_model/pos052000.model
# 21    0   5            2000    /home/pratik/crf_model/pos052000.model
# 22    0   5            3000    /home/pratik/crf_model/pos053000.model
# 23    0   5            3000    /home/pratik/crf_model/pos053000.model
# 24    0   5            4000    /home/pratik/crf_model/pos054000.model
# 25    0   5            4000    /home/pratik/crf_model/pos054000.model
# 26    0   5            5000    /home/pratik/crf_model/pos055000.model
# 27    0   5            5000    /home/pratik/crf_model/pos055000.model
# 28    0   5            6000    /home/pratik/crf_model/pos056000.model
# 29    0   5            6000    /home/pratik/crf_model/pos056000.model
# ..   ..  ..             ...                                       ...
# 132  10   5            4000   /home/pratik/crf_model/pos1054000.model
# 133  10   5            4000   /home/pratik/crf_model/pos1054000.model
# 134  10   5            5000   /home/pratik/crf_model/pos1055000.model
# 135  10   5            5000   /home/pratik/crf_model/pos1055000.model
# 136  10   5            6000   /home/pratik/crf_model/pos1056000.model
# 137  10   5            6000   /home/pratik/crf_model/pos1056000.model
# 138  10   5            7000   /home/pratik/crf_model/pos1057000.model
# 139  10   5            7000   /home/pratik/crf_model/pos1057000.model
# 140  10   5            8000   /home/pratik/crf_model/pos1058000.model
# 141  10   5            8000   /home/pratik/crf_model/pos1058000.model
# 142  10   5            9000   /home/pratik/crf_model/pos1059000.model
# 143  10   5            9000   /home/pratik/crf_model/pos1059000.model
# 144  10  10            1000  /home/pratik/crf_model/pos10101000.model
# 145  10  10            1000  /home/pratik/crf_model/pos10101000.model
# 146  10  10            2000  /home/pratik/crf_model/pos10102000.model
# 147  10  10            2000  /home/pratik/crf_model/pos10102000.model
# 148  10  10            3000  /home/pratik/crf_model/pos10103000.model
# 149  10  10            3000  /home/pratik/crf_model/pos10103000.model
# 150  10  10            4000  /home/pratik/crf_model/pos10104000.model
# 151  10  10            4000  /home/pratik/crf_model/pos10104000.model
# 152  10  10            5000  /home/pratik/crf_model/pos10105000.model
# 153  10  10            5000  /home/pratik/crf_model/pos10105000.model
# 154  10  10            6000  /home/pratik/crf_model/pos10106000.model
# 155  10  10            6000  /home/pratik/crf_model/pos10106000.model
# 156  10  10            7000  /home/pratik/crf_model/pos10107000.model
# 157  10  10            7000  /home/pratik/crf_model/pos10107000.model
# 158  10  10            8000  /home/pratik/crf_model/pos10108000.model
# 159  10  10            8000  /home/pratik/crf_model/pos10108000.model
# 160  10  10            9000  /home/pratik/crf_model/pos10109000.model
# 161  10  10            9000  /home/pratik/crf_model/pos10109000.model
#
#                                                 result train/test Iprecision  \
# 0                 precision    recall  f1-score   s...       test       0.92
# 1                 precision    recall  f1-score   s...      train       0.97
# 2                 precision    recall  f1-score   s...       test       0.92
# 3                 precision    recall  f1-score   s...      train       0.97
# 4                 precision    recall  f1-score   s...       test       0.91
# 5                 precision    recall  f1-score   s...      train       0.97
# 6                 precision    recall  f1-score   s...       test       0.91
# 7                 precision    recall  f1-score   s...      train       0.97
# 8                 precision    recall  f1-score   s...       test       0.91
# 9                 precision    recall  f1-score   s...      train       0.97
# 10                precision    recall  f1-score   s...       test       0.91
# 11                precision    recall  f1-score   s...      train       0.97
# 12                precision    recall  f1-score   s...       test       0.91
# 13                precision    recall  f1-score   s...      train       0.97
# 14                precision    recall  f1-score   s...       test       0.91
# 15                precision    recall  f1-score   s...      train       0.97
# 16                precision    recall  f1-score   s...       test       0.91
# 17                precision    recall  f1-score   s...      train       0.97
# 18                precision    recall  f1-score   s...       test       0.93
# 19                precision    recall  f1-score   s...      train       0.92
# 20                precision    recall  f1-score   s...       test       0.93
# 21                precision    recall  f1-score   s...      train       0.92
# 22                precision    recall  f1-score   s...       test       0.93
# 23                precision    recall  f1-score   s...      train       0.92
# 24                precision    recall  f1-score   s...       test       0.93
# 25                precision    recall  f1-score   s...      train       0.92
# 26                precision    recall  f1-score   s...       test       0.93
# 27                precision    recall  f1-score   s...      train       0.92
# 28                precision    recall  f1-score   s...       test       0.93
# 29                precision    recall  f1-score   s...      train       0.92
# ..                                                 ...        ...        ...
# 132               precision    recall  f1-score   s...       test       0.92
# 133               precision    recall  f1-score   s...      train       0.90
# 134               precision    recall  f1-score   s...       test       0.92
# 135               precision    recall  f1-score   s...      train       0.90
# 136               precision    recall  f1-score   s...       test       0.92
# 137               precision    recall  f1-score   s...      train       0.90
# 138               precision    recall  f1-score   s...       test       0.92
# 139               precision    recall  f1-score   s...      train       0.90
# 140               precision    recall  f1-score   s...       test       0.92
# 141               precision    recall  f1-score   s...      train       0.90
# 142               precision    recall  f1-score   s...       test       0.92
# 143               precision    recall  f1-score   s...      train       0.90
# 144               precision    recall  f1-score   s...       test       0.91
# 145               precision    recall  f1-score   s...      train       0.90
# 146               precision    recall  f1-score   s...       test       0.91
# 147               precision    recall  f1-score   s...      train       0.90
# 148               precision    recall  f1-score   s...       test       0.91
# 149               precision    recall  f1-score   s...      train       0.90
# 150               precision    recall  f1-score   s...       test       0.91
# 151               precision    recall  f1-score   s...      train       0.90
# 152               precision    recall  f1-score   s...       test       0.91
# 153               precision    recall  f1-score   s...      train       0.90
# 154               precision    recall  f1-score   s...       test       0.91
# 155               precision    recall  f1-score   s...      train       0.90
# 156               precision    recall  f1-score   s...       test       0.91
# 157               precision    recall  f1-score   s...      train       0.90
# 158               precision    recall  f1-score   s...       test       0.91
# 159               precision    recall  f1-score   s...      train       0.90
# 160               precision    recall  f1-score   s...       test       0.91
# 161               precision    recall  f1-score   s...      train       0.90
#
#     Irecall If_score Nprecision Nrecall Nf_score precision recall f_score
# 0      0.88     0.90       0.83    0.88     0.85      0.88   0.88    0.88
# 1      0.98     0.97       0.97    0.96     0.97      0.97   0.97    0.97
# 2      0.87     0.89       0.82    0.88     0.85      0.88   0.87    0.87
# 3      0.97     0.97       0.97    0.96     0.97      0.97   0.97    0.97
# 4      0.87     0.89       0.81    0.87     0.84      0.87   0.87    0.87
# 5      0.97     0.97       0.97    0.96     0.97      0.97   0.97    0.97
# 6      0.87     0.89       0.81    0.87     0.84      0.87   0.87    0.87
# 7      0.97     0.97       0.97    0.96     0.97      0.97   0.97    0.97
# 8      0.87     0.89       0.81    0.87     0.84      0.87   0.87    0.87
# 9      0.97     0.97       0.97    0.96     0.97      0.97   0.97    0.97
# 10     0.87     0.89       0.81    0.87     0.84      0.87   0.87    0.87
# 11     0.97     0.97       0.97    0.96     0.97      0.97   0.97    0.97
# 12     0.87     0.89       0.81    0.87     0.84      0.87   0.87    0.87
# 13     0.97     0.97       0.97    0.96     0.97      0.97   0.97    0.97
# 14     0.87     0.89       0.81    0.87     0.84      0.87   0.87    0.87
# 15     0.97     0.97       0.97    0.96     0.97      0.97   0.97    0.97
# 16     0.87     0.89       0.81    0.87     0.84      0.87   0.87    0.87
# 17     0.97     0.97       0.97    0.96     0.97      0.97   0.97    0.97
# 18     0.89     0.91       0.84    0.89     0.87      0.89   0.89    0.89
# 19     0.90     0.91       0.88    0.90     0.89      0.90   0.90    0.90
# 20     0.89     0.91       0.84    0.89     0.87      0.89   0.89    0.89
# 21     0.90     0.91       0.88    0.90     0.89      0.90   0.90    0.90
# 22     0.89     0.91       0.84    0.89     0.87      0.89   0.89    0.89
# 23     0.90     0.91       0.88    0.90     0.89      0.90   0.90    0.90
# 24     0.89     0.91       0.84    0.89     0.87      0.89   0.89    0.89
# 25     0.90     0.91       0.88    0.90     0.89      0.90   0.90    0.90
# 26     0.89     0.91       0.84    0.89     0.87      0.89   0.89    0.89
# 27     0.90     0.91       0.88    0.90     0.89      0.90   0.90    0.90
# 28     0.89     0.91       0.84    0.89     0.87      0.89   0.89    0.89
# 29     0.90     0.91       0.88    0.90     0.89      0.90   0.90    0.90
# ..      ...      ...        ...     ...      ...       ...    ...     ...
# 132    0.88     0.90       0.83    0.88     0.85      0.88   0.88    0.88
# 133    0.88     0.89       0.85    0.88     0.86      0.88   0.88    0.88
# 134    0.88     0.90       0.83    0.88     0.85      0.88   0.88    0.88
# 135    0.88     0.89       0.85    0.88     0.86      0.88   0.88    0.88
# 136    0.88     0.90       0.83    0.88     0.85      0.88   0.88    0.88
# 137    0.88     0.89       0.85    0.88     0.86      0.88   0.88    0.88
# 138    0.88     0.90       0.83    0.88     0.85      0.88   0.88    0.88
# 139    0.88     0.89       0.85    0.88     0.86      0.88   0.88    0.88
# 140    0.88     0.90       0.83    0.88     0.85      0.88   0.88    0.88
# 141    0.88     0.89       0.85    0.88     0.86      0.88   0.88    0.88
# 142    0.88     0.90       0.83    0.88     0.85      0.88   0.88    0.88
# 143    0.88     0.89       0.85    0.88     0.86      0.88   0.88    0.88
# 144    0.88     0.90       0.83    0.87     0.85      0.88   0.88    0.88
# 145    0.88     0.89       0.85    0.87     0.86      0.88   0.87    0.87
# 146    0.88     0.90       0.83    0.87     0.85      0.88   0.88    0.88
# 147    0.88     0.89       0.85    0.87     0.86      0.88   0.87    0.87
# 148    0.88     0.90       0.83    0.87     0.85      0.88   0.88    0.88
# 149    0.88     0.89       0.85    0.87     0.86      0.88   0.87    0.87
# 150    0.88     0.90       0.83    0.87     0.85      0.88   0.88    0.88
# 151    0.88     0.89       0.85    0.87     0.86      0.88   0.87    0.87
# 152    0.88     0.90       0.83    0.87     0.85      0.88   0.88    0.88
# 153    0.88     0.89       0.85    0.87     0.86      0.88   0.87    0.87
# 154    0.88     0.90       0.83    0.87     0.85      0.88   0.88    0.88
# 155    0.88     0.89       0.85    0.87     0.86      0.88   0.87    0.87
# 156    0.88     0.90       0.83    0.87     0.85      0.88   0.88    0.88
# 157    0.88     0.89       0.85    0.87     0.86      0.88   0.87    0.87
# 158    0.88     0.90       0.83    0.87     0.85      0.88   0.88    0.88
# 159    0.88     0.89       0.85    0.87     0.86      0.88   0.87    0.87
# 160    0.88     0.90       0.83    0.87     0.85      0.88   0.88    0.88
# 161    0.88     0.89       0.85    0.87     0.86      0.88   0.87    0.87
#
# [162 rows x 15 columns]

# %%
test_result = result_pandas[result_pandas['train/test'] == 'test'][['Nprecision', 'Nrecall', 'Nf_score','c1','c2', 'max_iterations']]

# %%
test_result
# Out:
#     Nprecision Nrecall Nf_score  c1  c2  max_iterations
# 0         0.83    0.88     0.85   0   0            1000
# 2         0.82    0.88     0.85   0   0            2000
# 4         0.81    0.87     0.84   0   0            3000
# 6         0.81    0.87     0.84   0   0            4000
# 8         0.81    0.87     0.84   0   0            5000
# 10        0.81    0.87     0.84   0   0            6000
# 12        0.81    0.87     0.84   0   0            7000
# 14        0.81    0.87     0.84   0   0            8000
# 16        0.81    0.87     0.84   0   0            9000
# 18        0.84    0.89     0.87   0   5            1000
# 20        0.84    0.89     0.87   0   5            2000
# 22        0.84    0.89     0.87   0   5            3000
# 24        0.84    0.89     0.87   0   5            4000
# 26        0.84    0.89     0.87   0   5            5000
# 28        0.84    0.89     0.87   0   5            6000
# 30        0.84    0.89     0.87   0   5            7000
# 32        0.84    0.89     0.87   0   5            8000
# 34        0.84    0.89     0.87   0   5            9000
# 36        0.84    0.89     0.86   0  10            1000
# 38        0.84    0.89     0.86   0  10            2000
# 40        0.84    0.89     0.86   0  10            3000
# 42        0.84    0.89     0.86   0  10            4000
# 44        0.84    0.89     0.86   0  10            5000
# 46        0.84    0.89     0.86   0  10            6000
# 48        0.84    0.89     0.86   0  10            7000
# 50        0.84    0.89     0.86   0  10            8000
# 52        0.84    0.89     0.86   0  10            9000
# 54        0.83    0.89     0.86   5   0            1000
# 56        0.83    0.89     0.86   5   0            2000
# 58        0.83    0.89     0.86   5   0            3000
# ..         ...     ...      ...  ..  ..             ...
# 102       0.83    0.88     0.85   5  10            7000
# 104       0.83    0.88     0.85   5  10            8000
# 106       0.83    0.88     0.85   5  10            9000
# 108       0.83    0.88     0.85  10   0            1000
# 110       0.83    0.88     0.85  10   0            2000
# 112       0.83    0.88     0.85  10   0            3000
# 114       0.83    0.88     0.85  10   0            4000
# 116       0.83    0.88     0.85  10   0            5000
# 118       0.83    0.88     0.85  10   0            6000
# 120       0.83    0.88     0.85  10   0            7000
# 122       0.83    0.88     0.85  10   0            8000
# 124       0.83    0.88     0.85  10   0            9000
# 126       0.83    0.88     0.85  10   5            1000
# 128       0.83    0.88     0.85  10   5            2000
# 130       0.83    0.88     0.85  10   5            3000
# 132       0.83    0.88     0.85  10   5            4000
# 134       0.83    0.88     0.85  10   5            5000
# 136       0.83    0.88     0.85  10   5            6000
# 138       0.83    0.88     0.85  10   5            7000
# 140       0.83    0.88     0.85  10   5            8000
# 142       0.83    0.88     0.85  10   5            9000
# 144       0.83    0.87     0.85  10  10            1000
# 146       0.83    0.87     0.85  10  10            2000
# 148       0.83    0.87     0.85  10  10            3000
# 150       0.83    0.87     0.85  10  10            4000
# 152       0.83    0.87     0.85  10  10            5000
# 154       0.83    0.87     0.85  10  10            6000
# 156       0.83    0.87     0.85  10  10            7000
# 158       0.83    0.87     0.85  10  10            8000
# 160       0.83    0.87     0.85  10  10            9000
#
# [81 rows x 6 columns]

# %%
tagger = pycrfsuite.Tagger()
tagger.open(model_name)

y_pred = [tagger.tag(xseq) for xseq in X_test]

predictions_analysis = {'status': [], 'expected': [], 'predicted': [], 'word': []}
for i in range(len(y_pred)):
    for x, y, z in zip(y_pred[i], [x[1].split("=")[1] for x in X_test[i]], y_test[i]):
        #print("Word %s Prediction(%s) Expected(%s)" % (y, x, z))
        if x == z:
            predictions_analysis['status'].append(True)
        else:
            predictions_analysis['status'].append(False)
        predictions_analysis['predicted'].append(x)
        predictions_analysis['expected'].append(z)
        predictions_analysis['word'].append(y)

import numpy as np
from sklearn.metrics import classification_report

# Create a mapping of labels to indices
labels = {"N": 1, "I": 0}
print(len(y_pred))
# Convert the sequences of tags into a 1-dimensional array
predictions = np.array([labels[tag] for row in y_pred for tag in row])
truths = np.array([labels[tag] for row in y_test for tag in row])

# Print out the classification report
print(classification_report(
    truths, predictions,
    target_names=["I", "N"]))
# Out:
# 2623
#              precision    recall  f1-score   support
#
#           I       0.91      0.88      0.90      7148
#           N       0.83      0.87      0.85      4681
#
# avg / total       0.88      0.88      0.88     11829

# %%
pandas_prediction_analysis = pd.DataFrame.from_dict(predictions_analysis)

# %%
labels = np.array(pandas_prediction_analysis['expected'].map({'N': 1, 'I': 0 } ))
predictions = np.array(pandas_prediction_analysis['predicted'].map({'N': 1, 'I': 0 } ))

# %%
from sklearn.metrics import confusion_matrix
tn, fp, fn, tp  = confusion_matrix(labels, predictions).ravel()

# %%
tn, fp, fn, tp
# Out:
# (6284, 864, 594, 4087)

# %%
test_result.loc[test_result.Nf_score.argmax()]
# Out:
# Nprecision        0.84
# Nrecall           0.89
# Nf_score          0.87
# c1                   0
# c2                   5
# max_iterations    1000
# Name: 18, dtype: object

# %%
#result_pandas.to_csv()
#pandas_prediction_analysis.to_csv()

# %%
result_pandas.to_csv('crf_positive.csv')
# Out:
#      c1  c2  max_iterations                                model_name  \
# 0     0   0            1000    /home/pratik/crf_model/pos001000.model
# 1     0   0            1000    /home/pratik/crf_model/pos001000.model
# 2     0   0            2000    /home/pratik/crf_model/pos002000.model
# 3     0   0            2000    /home/pratik/crf_model/pos002000.model
# 4     0   0            3000    /home/pratik/crf_model/pos003000.model
# 5     0   0            3000    /home/pratik/crf_model/pos003000.model
# 6     0   0            4000    /home/pratik/crf_model/pos004000.model
# 7     0   0            4000    /home/pratik/crf_model/pos004000.model
# 8     0   0            5000    /home/pratik/crf_model/pos005000.model
# 9     0   0            5000    /home/pratik/crf_model/pos005000.model
# 10    0   0            6000    /home/pratik/crf_model/pos006000.model
# 11    0   0            6000    /home/pratik/crf_model/pos006000.model
# 12    0   0            7000    /home/pratik/crf_model/pos007000.model
# 13    0   0            7000    /home/pratik/crf_model/pos007000.model
# 14    0   0            8000    /home/pratik/crf_model/pos008000.model
# 15    0   0            8000    /home/pratik/crf_model/pos008000.model
# 16    0   0            9000    /home/pratik/crf_model/pos009000.model
# 17    0   0            9000    /home/pratik/crf_model/pos009000.model
# 18    0   5            1000    /home/pratik/crf_model/pos051000.model
# 19    0   5            1000    /home/pratik/crf_model/pos051000.model
# 20    0   5            2000    /home/pratik/crf_model/pos052000.model
# 21    0   5            2000    /home/pratik/crf_model/pos052000.model
# 22    0   5            3000    /home/pratik/crf_model/pos053000.model
# 23    0   5            3000    /home/pratik/crf_model/pos053000.model
# 24    0   5            4000    /home/pratik/crf_model/pos054000.model
# 25    0   5            4000    /home/pratik/crf_model/pos054000.model
# 26    0   5            5000    /home/pratik/crf_model/pos055000.model
# 27    0   5            5000    /home/pratik/crf_model/pos055000.model
# 28    0   5            6000    /home/pratik/crf_model/pos056000.model
# 29    0   5            6000    /home/pratik/crf_model/pos056000.model
# ..   ..  ..             ...                                       ...
# 132  10   5            4000   /home/pratik/crf_model/pos1054000.model
# 133  10   5            4000   /home/pratik/crf_model/pos1054000.model
# 134  10   5            5000   /home/pratik/crf_model/pos1055000.model
# 135  10   5            5000   /home/pratik/crf_model/pos1055000.model
# 136  10   5            6000   /home/pratik/crf_model/pos1056000.model
# 137  10   5            6000   /home/pratik/crf_model/pos1056000.model
# 138  10   5            7000   /home/pratik/crf_model/pos1057000.model
# 139  10   5            7000   /home/pratik/crf_model/pos1057000.model
# 140  10   5            8000   /home/pratik/crf_model/pos1058000.model
# 141  10   5            8000   /home/pratik/crf_model/pos1058000.model
# 142  10   5            9000   /home/pratik/crf_model/pos1059000.model
# 143  10   5            9000   /home/pratik/crf_model/pos1059000.model
# 144  10  10            1000  /home/pratik/crf_model/pos10101000.model
# 145  10  10            1000  /home/pratik/crf_model/pos10101000.model
# 146  10  10            2000  /home/pratik/crf_model/pos10102000.model
# 147  10  10            2000  /home/pratik/crf_model/pos10102000.model
# 148  10  10            3000  /home/pratik/crf_model/pos10103000.model
# 149  10  10            3000  /home/pratik/crf_model/pos10103000.model
# 150  10  10            4000  /home/pratik/crf_model/pos10104000.model
# 151  10  10            4000  /home/pratik/crf_model/pos10104000.model
# 152  10  10            5000  /home/pratik/crf_model/pos10105000.model
# 153  10  10            5000  /home/pratik/crf_model/pos10105000.model
# 154  10  10            6000  /home/pratik/crf_model/pos10106000.model
# 155  10  10            6000  /home/pratik/crf_model/pos10106000.model
# 156  10  10            7000  /home/pratik/crf_model/pos10107000.model
# 157  10  10            7000  /home/pratik/crf_model/pos10107000.model
# 158  10  10            8000  /home/pratik/crf_model/pos10108000.model
# 159  10  10            8000  /home/pratik/crf_model/pos10108000.model
# 160  10  10            9000  /home/pratik/crf_model/pos10109000.model
# 161  10  10            9000  /home/pratik/crf_model/pos10109000.model
#
#                                                 result train/test Iprecision  \
# 0                 precision    recall  f1-score   s...       test       0.92
# 1                 precision    recall  f1-score   s...      train       0.97
# 2                 precision    recall  f1-score   s...       test       0.92
# 3                 precision    recall  f1-score   s...      train       0.97
# 4                 precision    recall  f1-score   s...       test       0.91
# 5                 precision    recall  f1-score   s...      train       0.97
# 6                 precision    recall  f1-score   s...       test       0.91
# 7                 precision    recall  f1-score   s...      train       0.97
# 8                 precision    recall  f1-score   s...       test       0.91
# 9                 precision    recall  f1-score   s...      train       0.97
# 10                precision    recall  f1-score   s...       test       0.91
# 11                precision    recall  f1-score   s...      train       0.97
# 12                precision    recall  f1-score   s...       test       0.91
# 13                precision    recall  f1-score   s...      train       0.97
# 14                precision    recall  f1-score   s...       test       0.91
# 15                precision    recall  f1-score   s...      train       0.97
# 16                precision    recall  f1-score   s...       test       0.91
# 17                precision    recall  f1-score   s...      train       0.97
# 18                precision    recall  f1-score   s...       test       0.93
# 19                precision    recall  f1-score   s...      train       0.92
# 20                precision    recall  f1-score   s...       test       0.93
# 21                precision    recall  f1-score   s...      train       0.92
# 22                precision    recall  f1-score   s...       test       0.93
# 23                precision    recall  f1-score   s...      train       0.92
# 24                precision    recall  f1-score   s...       test       0.93
# 25                precision    recall  f1-score   s...      train       0.92
# 26                precision    recall  f1-score   s...       test       0.93
# 27                precision    recall  f1-score   s...      train       0.92
# 28                precision    recall  f1-score   s...       test       0.93
# 29                precision    recall  f1-score   s...      train       0.92
# ..                                                 ...        ...        ...
# 132               precision    recall  f1-score   s...       test       0.92
# 133               precision    recall  f1-score   s...      train       0.90
# 134               precision    recall  f1-score   s...       test       0.92
# 135               precision    recall  f1-score   s...      train       0.90
# 136               precision    recall  f1-score   s...       test       0.92
# 137               precision    recall  f1-score   s...      train       0.90
# 138               precision    recall  f1-score   s...       test       0.92
# 139               precision    recall  f1-score   s...      train       0.90
# 140               precision    recall  f1-score   s...       test       0.92
# 141               precision    recall  f1-score   s...      train       0.90
# 142               precision    recall  f1-score   s...       test       0.92
# 143               precision    recall  f1-score   s...      train       0.90
# 144               precision    recall  f1-score   s...       test       0.91
# 145               precision    recall  f1-score   s...      train       0.90
# 146               precision    recall  f1-score   s...       test       0.91
# 147               precision    recall  f1-score   s...      train       0.90
# 148               precision    recall  f1-score   s...       test       0.91
# 149               precision    recall  f1-score   s...      train       0.90
# 150               precision    recall  f1-score   s...       test       0.91
# 151               precision    recall  f1-score   s...      train       0.90
# 152               precision    recall  f1-score   s...       test       0.91
# 153               precision    recall  f1-score   s...      train       0.90
# 154               precision    recall  f1-score   s...       test       0.91
# 155               precision    recall  f1-score   s...      train       0.90
# 156               precision    recall  f1-score   s...       test       0.91
# 157               precision    recall  f1-score   s...      train       0.90
# 158               precision    recall  f1-score   s...       test       0.91
# 159               precision    recall  f1-score   s...      train       0.90
# 160               precision    recall  f1-score   s...       test       0.91
# 161               precision    recall  f1-score   s...      train       0.90
#
#     Irecall If_score Nprecision Nrecall Nf_score precision recall f_score
# 0      0.88     0.90       0.83    0.88     0.85      0.88   0.88    0.88
# 1      0.98     0.97       0.97    0.96     0.97      0.97   0.97    0.97
# 2      0.87     0.89       0.82    0.88     0.85      0.88   0.87    0.87
# 3      0.97     0.97       0.97    0.96     0.97      0.97   0.97    0.97
# 4      0.87     0.89       0.81    0.87     0.84      0.87   0.87    0.87
# 5      0.97     0.97       0.97    0.96     0.97      0.97   0.97    0.97
# 6      0.87     0.89       0.81    0.87     0.84      0.87   0.87    0.87
# 7      0.97     0.97       0.97    0.96     0.97      0.97   0.97    0.97
# 8      0.87     0.89       0.81    0.87     0.84      0.87   0.87    0.87
# 9      0.97     0.97       0.97    0.96     0.97      0.97   0.97    0.97
# 10     0.87     0.89       0.81    0.87     0.84      0.87   0.87    0.87
# 11     0.97     0.97       0.97    0.96     0.97      0.97   0.97    0.97
# 12     0.87     0.89       0.81    0.87     0.84      0.87   0.87    0.87
# 13     0.97     0.97       0.97    0.96     0.97      0.97   0.97    0.97
# 14     0.87     0.89       0.81    0.87     0.84      0.87   0.87    0.87
# 15     0.97     0.97       0.97    0.96     0.97      0.97   0.97    0.97
# 16     0.87     0.89       0.81    0.87     0.84      0.87   0.87    0.87
# 17     0.97     0.97       0.97    0.96     0.97      0.97   0.97    0.97
# 18     0.89     0.91       0.84    0.89     0.87      0.89   0.89    0.89
# 19     0.90     0.91       0.88    0.90     0.89      0.90   0.90    0.90
# 20     0.89     0.91       0.84    0.89     0.87      0.89   0.89    0.89
# 21     0.90     0.91       0.88    0.90     0.89      0.90   0.90    0.90
# 22     0.89     0.91       0.84    0.89     0.87      0.89   0.89    0.89
# 23     0.90     0.91       0.88    0.90     0.89      0.90   0.90    0.90
# 24     0.89     0.91       0.84    0.89     0.87      0.89   0.89    0.89
# 25     0.90     0.91       0.88    0.90     0.89      0.90   0.90    0.90
# 26     0.89     0.91       0.84    0.89     0.87      0.89   0.89    0.89
# 27     0.90     0.91       0.88    0.90     0.89      0.90   0.90    0.90
# 28     0.89     0.91       0.84    0.89     0.87      0.89   0.89    0.89
# 29     0.90     0.91       0.88    0.90     0.89      0.90   0.90    0.90
# ..      ...      ...        ...     ...      ...       ...    ...     ...
# 132    0.88     0.90       0.83    0.88     0.85      0.88   0.88    0.88
# 133    0.88     0.89       0.85    0.88     0.86      0.88   0.88    0.88
# 134    0.88     0.90       0.83    0.88     0.85      0.88   0.88    0.88
# 135    0.88     0.89       0.85    0.88     0.86      0.88   0.88    0.88
# 136    0.88     0.90       0.83    0.88     0.85      0.88   0.88    0.88
# 137    0.88     0.89       0.85    0.88     0.86      0.88   0.88    0.88
# 138    0.88     0.90       0.83    0.88     0.85      0.88   0.88    0.88
# 139    0.88     0.89       0.85    0.88     0.86      0.88   0.88    0.88
# 140    0.88     0.90       0.83    0.88     0.85      0.88   0.88    0.88
# 141    0.88     0.89       0.85    0.88     0.86      0.88   0.88    0.88
# 142    0.88     0.90       0.83    0.88     0.85      0.88   0.88    0.88
# 143    0.88     0.89       0.85    0.88     0.86      0.88   0.88    0.88
# 144    0.88     0.90       0.83    0.87     0.85      0.88   0.88    0.88
# 145    0.88     0.89       0.85    0.87     0.86      0.88   0.87    0.87
# 146    0.88     0.90       0.83    0.87     0.85      0.88   0.88    0.88
# 147    0.88     0.89       0.85    0.87     0.86      0.88   0.87    0.87
# 148    0.88     0.90       0.83    0.87     0.85      0.88   0.88    0.88
# 149    0.88     0.89       0.85    0.87     0.86      0.88   0.87    0.87
# 150    0.88     0.90       0.83    0.87     0.85      0.88   0.88    0.88
# 151    0.88     0.89       0.85    0.87     0.86      0.88   0.87    0.87
# 152    0.88     0.90       0.83    0.87     0.85      0.88   0.88    0.88
# 153    0.88     0.89       0.85    0.87     0.86      0.88   0.87    0.87
# 154    0.88     0.90       0.83    0.87     0.85      0.88   0.88    0.88
# 155    0.88     0.89       0.85    0.87     0.86      0.88   0.87    0.87
# 156    0.88     0.90       0.83    0.87     0.85      0.88   0.88    0.88
# 157    0.88     0.89       0.85    0.87     0.86      0.88   0.87    0.87
# 158    0.88     0.90       0.83    0.87     0.85      0.88   0.88    0.88
# 159    0.88     0.89       0.85    0.87     0.86      0.88   0.87    0.87
# 160    0.88     0.90       0.83    0.87     0.85      0.88   0.88    0.88
# 161    0.88     0.89       0.85    0.87     0.86      0.88   0.87    0.87
#
# [162 rows x 15 columns]
